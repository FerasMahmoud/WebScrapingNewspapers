# %%
import requests
from bs4 import BeautifulSoup as bs
from html.parser import HTMLParser

URL = 'https://www.okaz.com.sa/sport/saudi/2047423'
page = requests.get(URL)

soup = bs(page.content, 'html.parser')

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="ar" xml:lang="ar" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    الليث يقلبها على الفتح ويقفز للوصافة - أخبار السعودية | صحيفة عكاظ
#   </title>
#   <meta content="text/html;charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="index,follow" name="ROBOTS"/>
#   <meta content="Arabic" name="language"/>
#   <meta content="Okaz" name="copyright"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <link href="https://www.okaz.com.sa/sport/saudi/2047423" rel="canonical"/>
#   <link href="https://www.okaz.com.sa/ampArticle/2047423" rel="amphtml"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" name="description"/>
#   <meta content="الليث,يقلبها,على,الفتح,ويقفز,للوصافة" name="keywords"/>
#   <meta content="891061" name="Idkeywords"/>
#   <meta content="article" name="pageType"/>
#   <meta content="https://www.okaz.com.sa/sport/saudi/2047423" name="url"/>
#   <meta content="2020-11-07 19:56:28" name="datePublished"/>
#   <meta content="2020-11-07 19:56:24" name="dateModified"/>
#   <meta content="صالح الحربي (جدة) saleh_a_alharbi@" name="author"/>
#   <meta content="ar" name="inLanguage"/>
#   <meta content="@OKAZ_online" name="twitter:site"/>
#   <meta content="@OKAZ_online" name="twitter:creator"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" name="twitter:title"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" name="twitter:description"/>
#   <meta content="1311831502273243" property="fb:app_id"/>
#   <meta content="https://www.okaz.com.sa/sport/saudi/2047423" property="og:url"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" property="og:title"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" property="og:description"/>
#   <meta content="article" property="og:type"/>
#   <meta content="Okaz" property="og:site_name"/>
#   <meta content="2020-11-07 19:56:28" property="article:published_time"/>
#   <meta content="صالح الحربي (جدة) saleh_a_alharbi@" property="article:author"/>
#   <meta content="رياضة" property="article:section"/>
#   <meta content="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" property="og:image"/>
#   <meta content="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" name="twitter:image"/>
#   <meta content="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" name="thumbnailUrl"/>
#   <meta content="2047423" itemprop="identifier"/>
#   <meta content="الليث يقلبها على الفتح ويقفز للوصافة" itemprop="headline"/>
#   <meta content="رياضة" itemprop="articleSection"/>
#   <meta content="2020-11-07T19:56:28+03:00" itemprop="datePublished"/>
#   <meta content="2020-11-07T19:56:28+03:00" itemprop="dateModified"/>
#   <meta content="https://www.okaz.com.sa/sport/saudi/2047423" itemprop="url"/>
#   <meta content="صالح الحربي (جدة) saleh_a_alharbi@" itemprop="author"/>
#   <meta content="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" itemprop="image"/>
#   <meta content="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" itemprop="thumbnailUrl"/>
#   <meta content="Okaz Newspaper - صحيفة عكاظ" itemprop="publisher"/>
#   <meta content="xN2Go65gxaIfTeer7iQ_eCAhc2RXLyDAQ8E88IQKwjw" name="google-site-verification"/>
#   <!--END SEO META TAGS-->
#   <link href="images/favicon-32x32.png" rel="icon" sizes="32x32" type="image/png">
#    <link as="font" crossorigin="anonymous" href="https://www.okaz.com.sa/themes/okazksa/fonts/subset-Cairo-Regular.woff2" rel="preload" type="font/woff2">
#     <link as="font" crossorigin="anonymous" href="https://www.okaz.com.sa/themes/okazksa/fonts/subset-Cairo-SemiBold.woff2" rel="preload" type="font/woff2"/>
#     <base href="https://www.okaz.com.sa/themes/okazksa/"/>
#     <link defer="" href="https://www.okaz.com.sa/themes/okazksa/css/style-one.min.css?v=0.96" rel="stylesheet"/>
#     <!--323kb-->
#     <!--code update related to ads-->
#     <!-- <script async='async' src='https://www.googletagservices.com/tag/js/gpt.js'></script>
#                         <script>
#                             var googletag = googletag || {};
#                             googletag.cmd = googletag.cmd || [];
#                         </script>-->
#     <script async="" src="https://securepubads.g.doubleclick.net/tag/js/gpt.js">
#     </script>
#     <script>
#      window.googletag = window.googletag || {cmd: []};
#   googletag.cmd.push(function() {
#
#
# //     var adSlot = googletag
# //    .defineSlot('/3387746/okaz_com_sa_sports/top', [[300, 250], [300, 50], [320, 50], [320, 100], [336, 280], [728, 90], [360, 300], [300, 100]], 'div-gpt-ad-top')
# //    .addService(googletag.pubads());
#
#       var adSlot = googletag
#      .defineSlot('/3387746/okaz_com_sa_sports/leftsidebar1', [[320, 50], [300, 50], [320, 100], [300, 250], [360, 300], [336, 280]], 'div-gpt-ad-leftsidebar1')
#     .addService(googletag.pubads());
#
# //      var adSlot = googletag
# //     .defineSlot('/3387746/okaz_com_sa_sports/leftsidebar3', [[320, 50], [300, 50], [320, 100], [300, 250], [336, 280]], 'div-gpt-ad-leftsidebar3')
# //     .addService(googletag.pubads());
#
#
#
#            var adSlot = googletag
#       .defineSlot('/3387746/ajlan_bros', [300, 150], 'div-gpt-ad-ajlan_bros')
#     .addService(googletag.pubads());
#
#
# if (screen.width > 960) {
#          var adSlot = googletag
#       .defineSlot('/3387746/okaz_com_sa_sports/leftsidebar2', [336, 280], 'div-gpt-ad-leftsidebar2')
#     .addService(googletag.pubads());
#
#
#          var adSlot = googletag
#       .defineSlot('/3387746/okaz_com_sa_sports/header', [970, 250], 'div-gpt-ad-header')
#     .addService(googletag.pubads());
#
# 	}
# 	 var adSlot = googletag
# 	.defineSlot('/3387746/okaz_com_sa_sports/1x1', [1, 1], 'div-gpt-ad-1x1')
# 	.addService(googletag.pubads());
#
#
# //   var mapping1= googletag.sizeMapping().
# //   addSize([320, 400], [[360, 300], [336, 280], [300, 250], [320, 100], [300, 100], [300, 50], [320, 50]]).
# //   addSize([320, 700], [[360, 300], [336, 280], [300, 250], [320, 100], [300, 100], [300, 50], [320, 50]]).
# //   addSize([750, 200], [[360, 300], [336, 280], [300, 250], [320, 100], [300, 100], [300, 50], [320, 50]]).
# //   addSize([1050, 200], [728,90]).build();
# //   adSlot.defineSizeMapping(mapping1);
#
#
#    var mapping2= googletag.sizeMapping().
#    addSize([320, 400], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
#    addSize([320, 700], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
#    addSize([750, 200], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
#    addSize([1050, 200], [336,280]).build()
#    adSlot.defineSizeMapping(mapping2);
#
# //   var mapping3= googletag.sizeMapping().
# //   addSize([320, 400], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
# //   addSize([320, 700], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
# //   addSize([750, 200], [[360,300], [336,280], [300,250], [320,100], [300,50], [320,50]]).
# //   addSize([1050, 200], [336,280]).build()
# //      adSlot.defineSizeMapping(mapping3);
#
#    var mapping4= googletag.sizeMapping().
#    addSize([320, 400], [300,150]).
#    addSize([320, 700], [300,150]).
#    addSize([750, 200], [300,150]).
#    addSize([1050, 200], [300,150]).build();
#    adSlot.defineSizeMapping(mapping4);
#
#    var mapping5= googletag.sizeMapping(). //This should only appear on Desktop
#    addSize([320, 400], []).
#    addSize([320, 700], []).
#    addSize([750, 200], []).
#    addSize([1050, 200], [728,90]).build();
#    adSlot.defineSizeMapping(mapping5);
#
#    var mapping6= googletag.sizeMapping(). //This should only appear on Desktop
#    addSize([320, 400], []).
#    addSize([320, 700], []).
#    addSize([750, 200], []).
#    addSize([1050, 200], [[728, 90], [980, 120], [730, 100], [970, 250], [980, 90], [970, 90], [930, 180]]).build();
#    adSlot.defineSizeMapping(mapping6);
#
# 	var mapping7= googletag.sizeMapping().
# 	addSize([320, 400], [1,1]).
# 	addSize([320, 700], [1,1]).
# 	addSize([750, 200], [1,1]).
# 	addSize([1050, 200], [1,1]).build();
# 	adSlot.defineSizeMapping(mapping7);
#
#     googletag.pubads().enableSingleRequest();
#       googletag.pubads().collapseEmptyDivs();
#     googletag.enableServices();
#   });
#     </script>
#     <!-- Global site tag (gtag.js) - Google Analytics -->
#     <script async="" src="https://www.googletagmanager.com/gtag/js?id=UA-964786-1">
#     </script>
#     <script>
#      window.dataLayer = window.dataLayer || [];
# 	function gtag(){dataLayer.push(arguments);}
# 	gtag('js', new Date());
# 	setTimeout("gtag('event', '15_sec_read', {'Read':'15 sec'})",15000 );
# 	setTimeout("gtag('event', '30_sec_read', {'Read':'30 sec'})",30000 );
# 	gtag('config', 'UA-964786-1');
#     </script>
#     <!--{LT-Tags: Start}-->
#     <link href="https://tags.crwdcntrl.net" rel="preconnect"/>
#     <link href="https://bcp.crwdcntrl.net" rel="preconnect"/>
#     <link href="https://tags.crwdcntrl.net" rel="dns-prefetch"/>
#     <link href="https://bcp.crwdcntrl.net" rel="dns-prefetch"/>
#     <script>
#      ! function() {
#       var lotameClientId = '15787';
#       var lotameTagInput = {
#           data: {},
#           config: {
#             clientId: Number(lotameClientId)
#           }
#       };
#
#       // Lotame initialization
#       var lotameConfig = lotameTagInput.config || {};
#       var namespace = window['lotame_' + lotameConfig.clientId] = {};
#       namespace.config = lotameConfig;
#       namespace.data = lotameTagInput.data || {};
#       namespace.cmd = namespace.cmd || [];
#     } ();
#     </script>
#     <script async="" src="https://tags.crwdcntrl.net/lt/c/15787/lt.min.js">
#     </script>
#     <!--{LT-Tags: End}-->
#     <!--{IAS Tags: Start}-->
#     <script onload="window.__iasADX.start(930977)" src="https://static.adsafeprotected.com/iasADX.js">
#     </script>
#     <!--{IAS Tags: End}-->
#    </link>
#   </link>
#  </head>
#  <body>
#   <!-- Start Alexa Certify Javascript -->
#   <script>
#    _atrk_opts = { atrk_acct:"CgLHh1aIE700M2", domain:"okaz.com.sa",dynamic: true};
# (function() { var as = document.createElement('script'); as.type = 'text/javascript'; as.async = true; as.src = "https://d31qbv1cthcecs.cloudfront.net/atrk.js"; var s = document.getElementsByTagName('script')[0];s.parentNode.insertBefore(as, s); })();
#   </script>
#   <noscript>
#    <img alt="Õ�?í�?É ÚßÇÙ" height="1" src="https://d5nxst8fruw4z.cloudfront.net/atrk.gif?account=CgLHh1aIE700M2" style="display:none" width="1"/>
#   </noscript>
#   <!-- End Alexa Certify Javascript -->
#   <!-- Twitter universal website tag code -->
#   <script>
#    !function(e,t,n,s,u,a){e.twq||(s=e.twq=function(){s.exe?s.exe.apply(s,arguments):s.queue.push(arguments);
# },s.version='1.1',s.queue=[],u=t.createElement(n),u.async=!0,u.src='//static.ads-twitter.com/uwt.js',
# a=t.getElementsByTagName(n)[0],a.parentNode.insertBefore(u,a))}(window,document,'script');
# // Insert Twitter Pixel ID and Standard Event data below
# twq('init','o0b7a');
# twq('track','PageView');
#   </script>
#   <!-- End Twitter universal website tag code -->
#   <div id="fb-root">
#   </div>
#   <!--        <script>
#                             window.fbAsyncInit = function() {
#                               FB.init({
#                                 appId      : '{1311831502273243}',
#                                 cookie     : true,
#                                 xfbml      : true,
#                                 version    : '{v2.5}'
#                               });
#
#                               FB.AppEvents.logPageView();
#
#                             };
#
#                             (function(d, s, id){
#                                var js, fjs = d.getElementsByTagName(s)[0];
#                                if (d.getElementById(id)) {return;}
#                                js = d.createElement(s); js.id = id;
#                                js.src = "https://connect.facebook.net/en_US/sdk.js";
#                                fjs.parentNode.insertBefore(js, fjs);
#                              }(document, 'script', 'facebook-jssdk'));
#                           </script>-->
#   <script async="" crossorigin="anonymous" defer="" src="https://connect.facebook.net/en_GB/sdk.js#xfbml=1&amp;version=v3.3&amp;appId=1311831502273243&amp;autoLogAppEvents=1">
#   </script>
#   <input id="BASE_URL" type="hidden" value="https://www.okaz.com.sa/"/>
#   <!--HEADER-->
#   <div class="modal modal-edit js-panel" data-hash="modal" id="modal">
#   </div>
#   <div class="modal modal-edit js-panel" data-hash="disclaimer" id="disclaimer">
#   </div>
#   <div class="bar-alert">
#    <div class="shell">
#     <div class="bar-body">
#      <span class="bar-aside">
#       خبر عاجل
#      </span>
#      <div class="bar-content" id="breakingNews">
#       <ul>
#       </ul>
#      </div>
#      <!-- /.bar-content -->
#      <a class="bar-close">
#       <i class="fa fa-close">
#       </i>
#      </a>
#     </div>
#     <!-- /.bar-body -->
#    </div>
#    <!-- /.shell -->
#   </div>
#   <!-- /.bar-alert -->
#   <div class="wrapper">
#    <div class="bar" id="mainHeader">
#     <div class="shell">
#      <div class="bar-body">
#       <a class="logo" href="https://www.okaz.com.sa/">
#       </a>
#       <!--<div class="beta-site"></div>-->
#       <a class="btn-menu">
#        <span>
#        </span>
#       </a>
#       <div class="searchMobileBtn search-btn submitSearch visible-xs-block">
#        <i class="fa fa-search">
#        </i>
#       </div>
#       <div class="logInBtnMobile visible-xs-block">
#        <a href="https://www.okaz.com.sa/login">
#         <i class="fa fa-user">
#         </i>
#        </a>
#       </div>
#      </div>
#      <!-- /.bar-body -->
#     </div>
#     <!-- /.shell -->
#     <div class="search searchMobile visible-xs-block">
#      <label class="hidden" for="q">
#       ابحث
#      </label>
#      <input class="field search-field query" placeholder="ابحث" type="search"/>
#     </div>
#    </div>
#    <!-- /.bar -->
#    <header class="header">
#     <div class="shell">
#      <!--menu.tpl-->
#      <div class="header-content">
#       <!--    <a class="btn-menu">
#         <span class="close-menu"></span>
#     </a>-->
#       <div class="nav-wrapper">
#        <nav class="nav nav-main">
#         <div class="modal modal-search js-panel" data-hash="modal-search" id="modal-search">
#          <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-search">
#          </div>
#          <!-- /.modal-overlay js-panel-toggle js-panel-close -->
#          <div class="modal-container">
#           <div class="search">
#            <label class="hidden" for="q">
#             ابحث
#            </label>
#            <input class="field search-field query" placeholder="ابحث" type="search">
#             <button class="search-btn submitSearch">
#              <i class="fa fa-search">
#              </i>
#             </button>
#            </input>
#           </div>
#           <!-- /.search -->
#          </div>
#          <!-- /.modal-container -->
#         </div>
#         <!-- /.modal modal-search js-panel -->
#         <ul>
#          <li class="nav-logo mobile-hidden">
#           <a class="emblem" href="https://www.okaz.com.sa/">
#           </a>
#          </li>
#          <!-- /.nav-logo -->
#          <li class="nav-white nav-home" style="border-color: #fc6142;background-color: #fc6142">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/" style="border-color: ">
#            <span>
#             الرئيسية
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #00dac1;background-color: #00dac1">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/news" style="border-color: #00dac1">
#            <span>
#             أخبار
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #11e944;background-color: #11e944">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/sports" style="border-color: #11e944">
#            <span>
#             رياضة
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #40d1f2;background-color: #40d1f2">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/economy" style="border-color: #40d1f2">
#            <span>
#             اقتصاد
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #b156db;background-color: #b156db">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/culture" style="border-color: #b156db">
#            <span>
#             ثقافة و فن
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #ff896b;background-color: #ff896b">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/variety" style="border-color: #ff896b">
#            <span>
#             منوعات
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #ffc505;background-color: #ffc505">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/media/latest" style="border-color: #ffc505">
#            <span>
#             ملتيميديا
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="" style="border-color: #b07564;background-color: #b07564">
#           <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/articles" style="border-color: #b07564">
#            <span>
#             مقالات
#            </span>
#           </a>
#           <line style="background-color: ">
#           </line>
#          </li>
#          <li class="has-dropdown mobile-shown">
#           <a class="open" style="border-color: #6b7e89;position: relative;">
#            المزيد
#            <i class="fa fa-chevron-down tablet-shown">
#            </i>
#           </a>
#           <div class="dropdown">
#            <ul>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">
#               سعوديات
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/fashion">
#               أزياء
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/tourism">
#               سياحة
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">
#               الناس
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/investigation">
#               تحقيقات
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/technology">
#               تكنولوجيا
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">
#               صوت المواطن
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/Games">
#               ألعاب
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">
#               زوايا متخصصة
#              </a>
#             </li>
#             <li>
#              <a class="ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">
#               سوق عكاظ
#              </a>
#             </li>
#             <li>
#              <a class="animated" href="https://www.okaz.com.sa/digital">
#               تصفح عدد اليوم
#              </a>
#             </li>
#             <!--to fix ios mobile hiden menu we add 2 empty li-->
#             <li>
#             </li>
#             <li>
#             </li>
#            </ul>
#           </div>
#           <!-- /.dropdown -->
#          </li>
#          <!-- /.has-dropdown -->
#         </ul>
#        </nav>
#        <!-- /.nav nav-main -->
#        <nav class="nav nav-utilities">
#         <ul>
#          <li class="has-dropdown mobile-hidden grey">
#           <a>
#            المزيد
#            <i class="fa fa-chevron-down">
#            </i>
#           </a>
#           <div class="dropdown">
#            <ul>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">
#               سعوديات
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/fashion">
#               أزياء
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/tourism">
#               سياحة
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">
#               الناس
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/investigation">
#               تحقيقات
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/technology">
#               تكنولوجيا
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">
#               صوت المواطن
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/Games">
#               ألعاب
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">
#               زوايا متخصصة
#              </a>
#             </li>
#             <li class="">
#              <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">
#               سوق عكاظ
#              </a>
#             </li>
#            </ul>
#           </div>
#           <!-- /.dropdown -->
#          </li>
#          <!-- /.has-dropdown -->
#          <li class="nav-absolute">
#           <a class="nav-clear" href="../../add-article">
#            <i class="fa fa-camera">
#            </i>
#            <span class="tablet-shown">
#             إرسال مواد أو صور
#            </span>
#           </a>
#          </li>
#          <li class="nav-absolute" id="weather">
#           <a href="../../weather">
#            <!--						<span class="nav-link-secondary tablet-shown">الطقس</span>
#                         <img id="weatherImg" src="" alt="" >
#                         <span id="temperature">الطقس</span>-->
#            <span class="weather-svgicon" id="temperature">
#            </span>
#           </a>
#           <div class="dropdown">
#            <div class="weatherWidget">
#             <!--<iframe src="http://widgets.arabiaweather.com/getselectwidget/344?headcolor=undefined&extracolor=undefined&textcolor=undefined&daycolor=undefined&nightcolor=undefined&bgcolor=%23dad2ba&font_type=Arial&temperatureUnit=C&language_type=ar&location_ar_name=%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%20&location_en_name=Riyadh&ifBackground=true&iframe_width=300&" width="300" frameborder="0" height="250" style="box-shadow:0px 1px 5px -1px rgba(0,0,0,0.8);"></iframe>-->
#             <a class="weatherwidget-io" data-label_1="السعودية" data-label_2="الطقس" data-theme="original" href="https://forecast7.com/ar/23d8945d08/saudi-arabia/" style="width: 320px;">
#              طقس السعودية
#             </a>
#             <script>
#              !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src='https://weatherwidget.io/js/widget.min.js';fjs.parentNode.insertBefore(js,fjs);}}(document,'script','weatherwidget-io-js');
#             </script>
#            </div>
#           </div>
#           <!-- /.dropdown -->
#          </li>
#          <li class="nav-absolute nav-absolute-secondary">
#           <a class="nav-clear nav-clear-darker logInBtn" href="https://www.okaz.com.sa/login">
#            <i class="fa fa-user">
#            </i>
#            <span class="tablet-shown">
#             تسجيل الدخول
#            </span>
#           </a>
#          </li>
#          <li class="nav-search">
#           <a class="nav-clear js-panel-toggle" data-target="#modal-search" role="button">
#            <i class="fa fa-search">
#            </i>
#            <i class="fa fa-close">
#            </i>
#           </a>
#          </li>
#          <!-- /.nav-search -->
#         </ul>
#        </nav>
#        <!-- /.nav nav-utilities -->
#       </div>
#       <!-- /.nav-wrapper -->
#      </div>
#      <!-- /.header-content -->
#     </div>
#     <!-- /.shell -->
#    </header>
#    <!-- /.header -->
#    <div class="ajaxLoadedContent">
#     <!--CMS: 2047423-->
#     <!--NP: 891061-->
#     <!--ISOLD: 0-->
#     <!--OLD: 0-->
#     <!-- article-details.phtml -->
#     <div style="height:450px;">
#     </div>
#     <div class="modal modal-article js-panel article-visible" data-hash="modal-article" id="modal-article">
#      <div class="shell shell-medium">
#       <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-article">
#       </div>
#       <div class="modal-container">
#        <div class="ajax-loader">
#         <img alt="loader" class="img-responsive" src="images/small_loader.svg"/>
#        </div>
#        <a class="modal-nav modal-prev" href="https://www.okaz.com.sa/sport/saudi/2047422">
#         <span>
#          <i class="icon-arrow-right" style="background-image: none;">
#           <svg viewbox="0 0 20.25808 37.41076" xmlns="http://www.w3.org/2000/svg">
#            <defs>
#             <style>
#              .cls-1 {
#                                                 fill: none;
#                                                 stroke: #ccc;
#                                                 stroke-width: 2px;
#                                             }
#             </style>
#            </defs>
#            <title>
#             arrow-right
#            </title>
#            <g data-name="Layer 2" id="Layer_2">
#             <g data-name="Layer 1" id="Layer_1-2">
#              <g data-name="Layer 2" id="Layer_2-2">
#               <g data-name="PART 201.fw-Page 201" id="PART_201.fw-Page_201">
#                <polyline class="cls-1" points="1.161 36.71 18.847 18.71 0.704 0.71">
#                </polyline>
#               </g>
#              </g>
#             </g>
#            </g>
#           </svg>
#          </i>
#         </span>
#        </a>
#        <a class="modal-nav modal-next" href="https://www.okaz.com.sa/sport/saudi/2047437">
#         <span>
#          <i class="icon-arrow-left" style="background-image: none;">
#           <svg viewbox="0 0 20.2582 37.41076" xmlns="http://www.w3.org/2000/svg">
#            <title>
#             arrow-left
#            </title>
#            <g data-name="Layer 2" id="Layer_2">
#             <g data-name="PART%201.fw-Page%201" id="PART_201.fw-Page_201">
#              <polyline fill="none" points="19.554 0.71 1.411 18.71 19.097 36.71" stroke="#ccc" stroke-width="2">
#              </polyline>
#             </g>
#            </g>
#           </svg>
#          </i>
#         </span>
#        </a>
#        <div class="modal-close modal-close-secondary-new js-panel-toggle js-panel-close mobile-hidden is-current" data-sectionlink="https://www.okaz.com.sa/sports" data-target="#modal-article">
#        </div>
#        <input id="cmsArticleId" type="hidden" value="2047423"/>
#        <div class="modal-inner">
#         <div class="modal-inner-content">
#          <div id="printThis">
#           <article class="article-main" data-title="الليث يقلبها على الفتح ويقفز للوصافة" data-url="https://www.okaz.com.sa/sport/saudi/2047423">
#            <div class="ads-preview">
#             <div id="div-gpt-ad-header">
#              <script>
#               googletag.cmd.push(function() { googletag.display('div-gpt-ad-header'); });
#              </script>
#             </div>
#            </div>
#            <header class="article-head">
#             <div class="shell shell-secondary">
#              <h3 class="article-subtitle">
#              </h3>
#              <!-- /.article-subtitle -->
#              <h1 class="autoHeight">
#               الليث يقلبها على الفتح ويقفز للوصافة
#              </h1>
#              <div class="article-meta">
#               <!-- <div class="show-for-mobile"></div> -->
#               <ul class="list-meta-items header-top show-for-desktop">
#                <li class="media_article_publish_time">
#                 <p>
#                  <span class="tag" style="background-color: #11e944 ; margin-bottom: 0px;color:#fff;">
#                   رياضة
#                  </span>
#                  السبت 7 نوفمبر 2020  19:56
#                 </p>
#                </li>
#                <li>
#                 <a style="cursor: default;">
#                  صالح الحربي (جدة) saleh_a_alharbi@
#                 </a>
#                </li>
#                <li>
#                 <p>
#                  <i class="fa fa-eye">
#                  </i>
#                  40
#                  <span class="hidden-xs">
#                   مشاهدة
#                  </span>
#                 </p>
#                </li>
#               </ul>
#               <!-- /.list-meta-items -->
#              </div>
#              <!-- /.article-meta -->
#             </div>
#             <!-- /.shell shell-secondary -->
#            </header>
#            <!-- /.article-head -->
#            <div class="ads-preview" style="margin:10px auto;">
#             <div id="TopOkaz29">
#              <script>
#               window.googletag = window.googletag || {cmd: []};
#     googletag.cmd.push(function() {
#     googletag.defineSlot('/3387746/okaz_com_sa_news/top', [[360, 300], [336, 280], [728, 90], [300, 250], [320,100]], 'TopOkaz29').addService(googletag.pubads());
#     googletag.enableServices();
#     googletag.display('TopOkaz29');
#     });
#              </script>
#             </div>
#            </div>
#            <div class="article-body">
#             <div class="shell shell-secondary">
#              <div class="article-inner">
#               <div class="article-content">
#                <div class="addthis_toolbox socials-secondary article-social">
#                 <ul>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_facebook socials-facebook" href="javascript:void(0)">
#                    <p>
#                     <i class="fa fa-facebook">
#                     </i>
#                    </p>
#                   </a>
#                  </li>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_twitter socials-twitter" href="javascript:void(0)">
#                    <i class="fa fa-twitter">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="" href="javascript:void(0)">
#                    <i class="fa fa-linkedin">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_whatsapp socials-whatsapp" href="javascript:void(0)">
#                    <i class="fa fa-whatsapp">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/article/2047423" class="addthis_button_telegram socials-telegram" href="javascript:void(0)">
#                    <i class="fa fa-telegram">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_email socials-email" href="javascript:void(0)">
#                    <i class="fa fa-envelope">
#                    </i>
#                   </a>
#                  </li>
#                  <li>
#                   <a class="printArticle">
#                    <i class="fa fa-print">
#                    </i>
#                   </a>
#                  </li>
#                 </ul>
#                </div>
#                <!-- /.socials-secondary -->
#                <script type="text/javascript">
#                 var addthis_share = {
#                                                     url: "https://www.okaz.com.sa/sport/saudi/2047423",
#                                                     url_transforms: {
#                                                         shorten: {
#                                                             twitter: 'bitly',
#                                                             whatsapp: 'bitly',
#                                                             facebook: 'bitly',
#                                                             telegram: 'bitly',
#                                                             email: 'bitly'
#                                                         }
#                                                     },
#                                                     shorteners : {
#                                                         bitly : {}
#                                                     }
#                                                 }
#                </script>
#                <div class="article-entry">
#                 <!-- single-image.phtml-->
#                 <div class="article-entry">
#                  <figure class="articleImage" id="lightgallery">
#                   <div class="ratio">
#                    <div class="itemLightGallery" data-src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg">
#                     <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: contain;object-position: center center;"/>
#                    </div>
#                   </div>
#                   <a class="btn-popup popup-trigger multiple-trigger hidden-xs callLightGallery">
#                    <i class="fa fa-expand">
#                    </i>
#                   </a>
#                   <figcaption>
#                   </figcaption>
#                  </figure>
#                  <!-- <img class="img-responsive" style="max-width: 100%" width="100%"
#                              title="الليث يقلبها على الفتح ويقفز للوصافة"
#                              caption="" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg"> -->
#                  <!--<p class="bodyText">
#
# 	</p> -->
#                  <!-- /.list-tags -->
#                 </div>
#                 <!-- /.article-entry -->
#                 <!-- Article Author name -->
#                 <div class="article-actions-secondary">
#                  <a id="shrinkText">
#                   -A
#                  </a>
#                  <a id="enlargeText">
#                   +A
#                  </a>
#                 </div>
#                 <!-- /.article-actions-secondary -->
#                 <div class="article-actions-secondary">
#                  <a style="background: none;width: auto;cursor: default;">
#                   صالح الحربي (جدة) saleh_a_alharbi@
#                  </a>
#                 </div>
#                 <div class="bodyText">
#                  قلب فريق الشباب تأخره بهدف من أمام مضيفه الفتح إلى فوز مستحق بثلاثة أهداف لهدف، في اللقاء الذي جمع بينهما على استاد مدينة الأمير عبدالله بن جلوي، ضمن لقاءات جولة «لنلهم العالم بقمتنا» لدوري كأس الأمير محمد بن سلمان للمحترفين.
#                  <br/>
#                  <br/>
#                  بدأ الشباب بهجمات متتالية وسط تحفظ دفاعي من الفتح الذي استغل هجمة مرتدة قادها جوستاف ليتحصل على ركلة جزاء تقدم لها سفيان بن دبكة ليحرز الهدف الأول للفتح (د:37).
#                  <!--mobileAd-->
#                  <div class="ads-preview">
#                   <div id="leftsidebar3">
#                    <script>
#                     window.googletag = window.googletag || {cmd: []};googletag.cmd.push(function() {googletag.defineSlot('/3387746/okaz_com_sa_news/leftsidebar3', [[360, 300], [336, 280], [300, 250]],'leftsidebar3').addService(googletag.pubads());googletag.enableServices();googletag.display('leftsidebar3');});
#                    </script>
#                   </div>
#                  </div>
#                  <br/>
#                  <br/>
#                  وفي الشوط الثاني قلب الشباب الطاولة على الفتح وأحرز هدفين في خمس دقائق، وفي الوقت بدل الضائع أضاف الهدف الثالث، وجاءت الأهداف الثلاثة للشباب عن طريق كل من: تركي العمار (هدفين د:74، 90+6)، وفابيو مارتينز (د:78)، ومنح حكم اللقاء فيصل البلوي بطاقة حمراء للاعب الفتح حسن الحبيب (د:85)، وبعد 8 دقائق كوقت بدل ضائع أعلن الحكم نهاية اللقاء بفوز الشباب بهدفين لهدف.
#                  <br/>
#                  <br/>
#                  وبهذه النتيجة قفز الشباب للمركز الثاني برصيد 10 نقاط، متساوياً مع المتصدر الهلال الذي يتفوق بفارق الأهداف، فيما تجمد رصيد الفتح عند 7 نقاط في المركز الخامس.
#                  <div class="clear">
#                  </div>
#                  <br>
#                   <div class="pagingWrap" style="display:none;">
#                    <a class="button grey prevBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=0" style="display:none;">
#                     &lt; Previous Page
#                    </a>
#                    <a class="button grey nextBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=2" style="display:none;">
#                     Next Page &gt;
#                    </a>
#                   </div>
#                  </br>
#                 </div>
#                 <div class="bodyTextToPrint">
#                 </div>
#                 <ul class="list-tags">
#                 </ul>
#                 <!-- /.list-tags -->
#                </div>
#                <!-- /.article-entry -->
#               </div>
#               <!-- /.article-content -->
#               <aside class="article-aside">
#                <ul class="widgets-tertiary">
#                 <li class="widget">
#                  <div class="ads-preview">
#                   <div id="div-gpt-ad-leftsidebar1">
#                    <script>
#                     googletag.cmd.push(function() { googletag.display('div-gpt-ad-leftsidebar1'); });
#                    </script>
#                   </div>
#                  </div>
#                 </li>
#                 <li class="widget widget-subscribe">
#                  <!--<h4 class="widget-title">إشترك بالنشرة الإلكترونية</h4>-->
#                  <!-- /.widget-title -->
#                  <div class="subscribe">
#                   <a href="https://www.okaz.com.sa/login#register">
#                    <button class="btn form-btn">
#                     إشترك بالنشرة الإلكترونية
#                    </button>
#                   </a>
#                   <!--                                                            <form>
#                                                                                                                             <div class="subscribe-inner">
#                                                                                                                                 <label for="mail" class="hidden">البريد
#                                                                                                                                     الإلكتروني</label>
#
#                                                                                                                                 <input type="email" id="mail" name="mail" value=""
#                                                                                                                                        placeholder="البريد الإلكتروني"
#                                                                                                                                        class="field subscribe-field"/>
#
#                                                                                                                                 <input type="submit" value="إشترك"
#                                                                                                                                        class="btn-secondary subscribe-btn"
#                                                                                                                                        onclick="NewsLetterSubscribe()"/>
#                                                                                                                             </div>
#                                                                                                                             <div class="result-message"></div>
#                                                                                                                             <div class="SubscribeRecaptcha">
#                                                                                                                                 <div class="form-actions form-recaptcha">
#                                                                                                                                     <div class="clear"></div>
#                                                                                                                                     <div class="g-recaptcha"
#                                                                                                                                          id="recaptchaRegister"   data-sitekey="6LfxP70UAAAAAC0TVQ_oIZIrZVugmXY8s-asC312"></div>
#                                                                                                                                     <div class="hidden recaptchaText recaptchaTextPage">
#                                                                                                                                         الرمز خاطئ حاول مرة أخرى
#                                                                                                                                     </div>
#                                                                                                                                 </div>
#                                                                                                                             </div>
#                                                                                                                         </form>-->
#                  </div>
#                  <!-- /.subscribe -->
#                 </li>
#                 <!-- /.widget widget-subscribe -->
#                 <li class="widget">
#                  <div class="ads-preview">
#                   <div id="div-gpt-ad-ajlan_bros">
#                    <script>
#                     googletag.cmd.push(function() { googletag.display('div-gpt-ad-ajlan_bros'); });
#                    </script>
#                   </div>
#                  </div>
#                 </li>
#                 <li class="widget widget-updates mobile-hidden widget-header">
#                  <div class="widget-head">
#                   <h4>
#                    أخبار شائعة
#                   </h4>
#                  </div>
#                  <!-- /.widget-head -->
#                  <div class="widget-body">
#                   <div class="update update-medium tablet-hidden">
#                    <a class="ratio" href="https://www.okaz.com.sa/sport/saudi/2001328">
#                     <div>
#                      <figure class="update-image">
#                      </figure>
#                      <!-- /.update-image -->
#                      <img alt="عادل التويجري" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2019/12/18/1455901.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#                     </div>
#                     <header class="update-head">
#                      <h4 class="title-large">
#                       إيقاف الناقد الرياضي عادل التويجري
#                      </h4>
#                      <!-- /.title-large -->
#                     </header>
#                     <!-- /.update-head -->
#                    </a>
#                   </div>
#                   <!-- /.update update-medium tablet-hidden -->
#                   <ul class="updates-secondary">
#                    <li class="update-small">
#                     <a class="" href="https://www.okaz.com.sa/sport/saudi/2012826">
#                      <figure class="update-image" style="height: 58px;">
#                       <div class="ratio">
#                        <div>
#                         <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/02/29/1516676.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#                        </div>
#                       </div>
#                      </figure>
#                      <!-- /.update-image -->
#                      <div class="update-content">
#                       <h6>
#                        وفاة «رضيع» حضر مباراة الفتح والوحدة
#                       </h6>
#                       <span class="update-meta">
#                        السبت 29 فبراير 2020  20:11
#                       </span>
#                      </div>
#                      <!-- /.update-content -->
#                     </a>
#                    </li>
#                    <!-- /.update-small -->
#                    <li class="update-small">
#                     <a class="" href="https://www.okaz.com.sa/sport/international/2005434">
#                      <figure class="update-image" style="height: 58px;">
#                       <div class="ratio">
#                        <div>
#                         <img alt="المصارع لاباركا بعد سقوطه خارج الحلبة" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/01/14/1478929.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#                        </div>
#                       </div>
#                      </figure>
#                      <!-- /.update-image -->
#                      <div class="update-content">
#                       <h6>
#                        وفاة المصارع «لاباركا» متاثرا بإصابته أثناء النزال
#                       </h6>
#                       <span class="update-meta">
#                        الثلاثاء 14 يناير 2020  17:51
#                       </span>
#                      </div>
#                      <!-- /.update-content -->
#                     </a>
#                    </li>
#                    <!-- /.update-small -->
#                    <li class="update-small">
#                     <a class="" href="https://www.okaz.com.sa/sport/saudi/2004255">
#                      <figure class="update-image" style="height: 58px;">
#                       <div class="ratio">
#                        <div>
# ...
#                                     anHttpRequest.onreadystatechange = function () {
#                                         if (anHttpRequest.readyState == 4 && anHttpRequest.status == 200)
#                                             aCallback(anHttpRequest.responseText);
#                                     }
#
#                                     anHttpRequest.open("GET", aUrl, true);
#                                     anHttpRequest.send(null);
#                                 }
#                             }
#
#                             function incrementArticleVisitcount(articleId) {
#                                 var article_counter_url = "/ajax/article_count/" + articleId + "?ts=" + Date.now();
#                                 var client = new HttpClient();
#                                 client.get(article_counter_url, function (response) {
#                                     console.log(response);
#                                 });
#                             }
#
#                             //                var articleId = (document.getElementById('cmsArticleId'));
#                             //                if (articleId) {
#                             //                    incrementArticleVisitcount(articleId.value);
#                             //                }
#    </script>
#    <footer class="footer" id="mainFooter">
#     <div class="footer-content">
#      <div class="shell">
#       <div class="footer-cols">
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #00dac1">
#          <a href="https://www.okaz.com.sa/news">
#           أخبار
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/news/local">
#            محليات
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/news/politics">
#            سياسة
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #11e944">
#          <a href="https://www.okaz.com.sa/sports">
#           رياضة
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/sport/saudi">
#            السعودية
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/sport/arabian">
#            العربية
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/sport/international">
#            الدولية
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">
#            العاب منوعة
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">
#            مقابلات خاصة
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #40d1f2">
#          <a href="https://www.okaz.com.sa/economy">
#           اقتصاد
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/economy/saudi">
#            السعودية
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/economy/arabian">
#            العربية
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/economy/international">
#            الدولية
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #b156db">
#          <a href="https://www.okaz.com.sa/culture">
#           ثقافة و فن
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/culture/art">
#            فن
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/culture/culture">
#            ثقافة
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/culture/other">
#            اخرى
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #a8ad9b">
#          <a href="https://www.okaz.com.sa/souk-okaz">
#           سوق عكاظ
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">
#            عقار
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">
#            حراج
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title" style="border-color: #b07564">
#          <a href="https://www.okaz.com.sa/articles">
#           مقالات
#          </a>
#         </h5>
#         <!-- /.footer-title footer-title-red -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/authors">
#            كتاب الرأي
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">
#            نبض القراء
#           </a>
#          </li>
#         </ul>
#        </div>
#        <a class="footerText">
#        </a>
#        <div class="footer-col">
#         <h5 class="footer-title footer-title-lightgrey">
#          المزيد
#         </h5>
#         <!-- /.footer-title footer-title-lightgrey -->
#         <ul>
#          <li>
#           <a href="https://www.okaz.com.sa/saudi-women">
#            سعوديات
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/fashion">
#            أزياء
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/tourism">
#            سياحة
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/people-situations">
#            احوال الناس
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/investigation">
#            تحقيقات
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/technology">
#            تكنولوجيا
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/citizen-voice">
#            صوت المواطن
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/weather">
#            حالة الطقس
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/variety">
#            منوعات
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/Games">
#            ألعاب
#           </a>
#          </li>
#          <li>
#           <a href="https://www.okaz.com.sa/special-zones">
#            زوايا متخصصة
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- /.footer-col -->
#       </div>
#       <!-- /.footer-cols -->
#      </div>
#      <!-- /.shell -->
#     </div>
#     <!-- /.footer-content -->
#     <div class="footer-bar">
#      <div class="shell">
#       <div class="footer-inner">
#        <a class="logo" href="https://www.okaz.com.sa/">
#        </a>
#        <div class="storeBadges">
#         <div class="appleBadge">
#          <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank">
#          </a>
#         </div>
#         <div class="googleBadge">
#          <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#          </a>
#         </div>
#        </div>
#        <div class="socials">
#         <ul>
#          <li>
#           <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#            <i class="fa fa-facebook">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#            <i class="fa fa-twitter">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#            <i class="fa fa-instagram">
#            </i>
#           </a>
#          </li>
#          <li style="display: none;">
#           <a href="#">
#            <i class="fa fa-linkedin">
#            </i>
#           </a>
#          </li>
#          <li style="display: none;">
#           <a onclick="window.open('', '_blank');">
#            <i class="fa fa-google-plus">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#            <i class="fa fa-youtube-play">
#            </i>
#           </a>
#          </li>
#          <li style="display: none">
#           <a href="#">
#            <i class="fa fa-pinterest">
#            </i>
#           </a>
#          </li>
#          <li>
#           <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#            <i class="fa fa-rss">
#            </i>
#           </a>
#          </li>
#         </ul>
#        </div>
#        <!-- /.socials -->
#       </div>
#       <!-- /.footer-inner -->
#       <nav class="footer-nav">
#        <ul>
#         <li>
#          <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">
#           الشروط والأحكام
#          </a>
#         </li>
#         <li>
#          <a href="../../about-us">
#           حول المؤسسة
#          </a>
#         </li>
#         <li>
#          <a href="../../editorial-management">
#           إدارة التحرير
#          </a>
#         </li>
#         <!--				<li>
# 					<a href="../../advertise-with-us" >للإعلان</a>
# 				</li>-->
#         <li>
#          <a href="../../media-kit">
#           للإعلان
#          </a>
#         </li>
#         <li>
#          <a href="../../contact-us">
#           إتصل بنا
#          </a>
#         </li>
#         <li>
#          حقوق الملكية ©
#          <span class="okazcopyright">
#          </span>
#          <span>
#           عكاظ
#          </span>
#          2020. جميع الحقوق محفوظة
#         </li>
#        </ul>
#       </nav>
#       <!-- /.footer-nav -->
#      </div>
#      <!-- /.shell -->
#     </div>
#     <!-- /.footer-bar -->
#     <!--<div class="newsPress">
# 	<span>Powered by <a href="http://layoutintl.com" target="_blank">NewsPress</a></span>
# </div>-->
#     <input id="FOOTER_HEIGHT" type="hidden" value="">
#     </input>
#    </footer>
#    <script>
#     function EmbedScript() {
#                                     var _Impulser = window.parent.document.createElement('script');
#                                     _Impulser.type = 'text/javascript';
#                                     _Impulser.async = true;
#                                     _Impulser.src = ('https:' == window.parent.document.location.protocol ? 'https://' : 'http://') + 'impulse.forkcdn.com/impulse3/config/impulse.js';
#                                     var _scripter = window.parent.document.getElementsByTagName('script')[0];
#                                     _scripter.parentNode.insertBefore(_Impulser, _scripter);
#                                 }
#                                 ;
#                                 function inIframe() {
#                                     try {
#                                         return window.self !== window.top;
#                                     } catch (e) {
#                                         return true;
#                                     }
#                                 }
#                                 if (inIframe()) {
#                                     window.parent.$ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                     EmbedScript();
#                                 } else {
#                                     $ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                     EmbedScript();
#                                 }
#    </script>
#    <!-- the arrows for big-page -->
#    <script src="images/icons/grunticon.loader.js" type="text/javascript">
#    </script>
#    <script>
#     grunticon(["images/icons/icons.data.svg.css", "images/icons/icons.data.png.css", "images/icons/icons.fallback.css"], grunticon.svgLoadedCallback);
#    </script>
#    <!-- the arrows for big-page -->
#    <script async="" rel="preconnect" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js">
#    </script>
#    <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js">
#    </script>
#    <!-- Fall back to a local copy of jQuery if the CDN fails-->
#    <noscript>
#     <script src="https://www.okaz.com.sa/js/jquery.min.js">
#     </script>
#    </noscript>
#    <script defer="" src="https://www.okaz.com.sa/themes/okazksa/js/script-one.js?v=0.73">
#    </script>
#    <!--515kb-->
#    <!-- Go to www.addthis.com/dashboard to customize your tools replace  async="async" by defer -->
#    <script defer="" rel="preconnect" src="//s7.addthis.com/js/300/addthis_widget.js&amp;async=1#pubid=ra-57d7a6b3b67f6bef" type="text/javascript">
#    </script>
#    <!--Vibe_okaz-->
#    <script async="" id="_forkIAVScript" src="//vibecdn.forkcdn.com/Inarticle/iav.js?publisher=okaz">
#    </script>
#    <noscript>
#     <a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a97c95f6&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#      <img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4210&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a97c95f6"/>
#     </a>
#    </noscript>
#    <noscript>
#     <a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a87267e0&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank">
#      <img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4211&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a87267e0"/>
#     </a>
#    </noscript>
#    <!--Vibe_okaz-->
#    <div class="ajax-loader">
#     <img alt="loader" class="img-responsive" src="images/small_loader.svg">
#     </img>
#    </div>
#    <script>
#     $(function(){
# 									$(window).scroll(function(){
# 										if($(window).scrollTop() > 100){
# 											$(".stickyAdsBottom").css("display","block");
# 										}else{
# 											$(".stickyAdsBottom").css("display","none");
# 										}
# 									});
# 								});
#    </script>
#    <script type="text/javascript">
#     $(function () {
#                                         if (getCookie('device') == 'mobile' || getCookie('device') == 'tablet'){
# 											$("#modal-article").clone().appendTo("body");
# 											$("#modal-article").remove();
# 										}
#                                     });
#    </script>
#    <div>
#     <!-- Desktop+Mobile Banner -->
#     <div id="div-gpt-ad-1x1">
#      <script>
#       googletag.cmd.push(function() { googletag.display('div-gpt-ad-1x1'); });
#      </script>
#     </div>
#    </div>
#    <!-- google recaptcha-->
#    <script async="" src="https://www.google.com/recaptcha/api.js">
#    </script>
#    <!-- BEGIN EFFECTIVE MEASURE CODE -->
#    <script>
#     (function () {
#                                     var em = document.createElement('script');
#                                     em.type = 'text/javascript';
#                                     em.async = true;
#                                     em.src = ('https:' == document.location.protocol ? 'https://me-ssl' : 'http://me-cdn') + '.effectivemeasure.net/em.js';
#                                     var s = document.getElementsByTagName('script')[0];
#                                     s.parentNode.insertBefore(em, s);
#                                 })();
#    </script>
#    <noscript>
#     <img alt="Okaz Effective Measure" src="http://me.effectivemeasure.net/em_image" style="position:absolute; left:-5px;">
#     </img>
#    </noscript>
#    <!-- END EFFECTIVE MEASURE CODE -->
#   </div>
#  </body>
# </html>

# %%
print(soup.title.string)
# Out:
# الليث يقلبها على الفتح ويقفز للوصافة - أخبار السعودية | صحيفة عكاظ

# %%
soup.find_all('div')
# Out:
# [<div id="fb-root"></div>,
#  <div class="modal modal-edit js-panel" data-hash="modal" id="modal"> </div>,
#  <div class="modal modal-edit js-panel" data-hash="disclaimer" id="disclaimer"> </div>,
#  <div class="bar-alert">
#  <div class="shell">
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div><!-- /.bar-body -->
#  </div><!-- /.shell -->
#  </div>,
#  <div class="shell">
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div><!-- /.bar-body -->
#  </div>,
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div>,
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div>,
#  <div class="wrapper">
#  <div class="bar" id="mainHeader">
#  <div class="shell">
#  <div class="bar-body">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <!--<div class="beta-site"></div>-->
#  <a class="btn-menu">
#  <span></span>
#  </a>
#  <div class="searchMobileBtn search-btn submitSearch visible-xs-block">
#  <i class="fa fa-search"></i>
#  </div>
#  <div class="logInBtnMobile visible-xs-block">
#  <a href="https://www.okaz.com.sa/login">
#  <i class="fa fa-user"></i>
#  </a>
#  </div>
#  </div><!-- /.bar-body -->
#  </div><!-- /.shell -->
#  <div class="search searchMobile visible-xs-block">
#  <label class="hidden" for="q">ابحث</label>
#  <input class="field search-field query" placeholder="ابحث" type="search"/>
#  </div>
#  </div><!-- /.bar -->
#  <header class="header">
#  <div class="shell">
#  <!--menu.tpl-->
#  <div class="header-content">
#  <!--    <a class="btn-menu">
#          <span class="close-menu"></span>
#      </a>-->
#  <div class="nav-wrapper">
#  <nav class="nav nav-main">
#  <div class="modal modal-search js-panel" data-hash="modal-search" id="modal-search">
#  <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-search"></div><!-- /.modal-overlay js-panel-toggle js-panel-close -->
#  <div class="modal-container">
#  <div class="search">
#  <label class="hidden" for="q">ابحث</label>
#  <input class="field search-field query" placeholder="ابحث" type="search">
#  <button class="search-btn submitSearch">
#  <i class="fa fa-search"></i>
#  </button>
#  </input></div><!-- /.search -->
#  </div><!-- /.modal-container -->
#  </div><!-- /.modal modal-search js-panel -->
#  <ul>
#  <li class="nav-logo mobile-hidden">
#  <a class="emblem" href="https://www.okaz.com.sa/"></a>
#  </li><!-- /.nav-logo -->
#  <li class="nav-white nav-home" style="border-color: #fc6142;background-color: #fc6142">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/" style="border-color: ">
#  <span>
#                                  الرئيسية                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #00dac1;background-color: #00dac1">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/news" style="border-color: #00dac1">
#  <span>
#                                  أخبار                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #11e944;background-color: #11e944">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/sports" style="border-color: #11e944">
#  <span>
#                                  رياضة                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #40d1f2;background-color: #40d1f2">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/economy" style="border-color: #40d1f2">
#  <span>
#                                  اقتصاد                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #b156db;background-color: #b156db">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/culture" style="border-color: #b156db">
#  <span>
#                                  ثقافة و فن                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #ff896b;background-color: #ff896b">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/variety" style="border-color: #ff896b">
#  <span>
#                                  منوعات                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #ffc505;background-color: #ffc505">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/media/latest" style="border-color: #ffc505">
#  <span>
#                                  ملتيميديا                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #b07564;background-color: #b07564">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/articles" style="border-color: #b07564">
#  <span>
#                                  مقالات                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="has-dropdown mobile-shown">
#  <a class="open" style="border-color: #6b7e89;position: relative;">
#                          المزيد
#
#                          <i class="fa fa-chevron-down tablet-shown"></i>
#  </a>
#  <div class="dropdown">
#  <ul>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">الناس</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </li>
#  <li>
#  <a class="animated" href="https://www.okaz.com.sa/digital">تصفح عدد اليوم</a>
#  </li>
#  <!--to fix ios mobile hiden menu we add 2 empty li-->
#  <li>   </li>
#  <li>     </li>
#  </ul>
#  </div><!-- /.dropdown -->
#  </li><!-- /.has-dropdown -->
#  </ul>
#  </nav><!-- /.nav nav-main -->
#  <nav class="nav nav-utilities">
#  <ul>
#  <li class="has-dropdown mobile-hidden grey">
#  <a>
#                          المزيد    <i class="fa fa-chevron-down"></i>
#  </a>
#  <div class="dropdown">
#  <ul>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">الناس</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </li>
#  </ul>
#  </div><!-- /.dropdown -->
#  </li><!-- /.has-dropdown -->
#  <li class="nav-absolute">
#  <a class="nav-clear" href="../../add-article">
#  <i class="fa fa-camera"></i>
#  <span class="tablet-shown">إرسال مواد أو صور</span>
#  </a>
#  </li>
#  <li class="nav-absolute" id="weather">
#  <a href="../../weather">
#  <!--						<span class="nav-link-secondary tablet-shown">الطقس</span>
#                          <img id="weatherImg" src="" alt="" >
#                          <span id="temperature">الطقس</span>-->
#  <span class="weather-svgicon" id="temperature"></span>
#  </a>
#  <div class="dropdown">
#  <div class="weatherWidget">
#  <!--<iframe src="http://widgets.arabiaweather.com/getselectwidget/344?headcolor=undefined&extracolor=undefined&textcolor=undefined&daycolor=undefined&nightcolor=undefined&bgcolor=%23dad2ba&font_type=Arial&temperatureUnit=C&language_type=ar&location_ar_name=%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%20&location_en_name=Riyadh&ifBackground=true&iframe_width=300&" width="300" frameborder="0" height="250" style="box-shadow:0px 1px 5px -1px rgba(0,0,0,0.8);"></iframe>-->
#  <a class="weatherwidget-io" data-label_1="السعودية" data-label_2="الطقس" data-theme="original" href="https://forecast7.com/ar/23d8945d08/saudi-arabia/" style="width: 320px;">طقس السعودية</a>
#  <script>
#                          !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src='https://weatherwidget.io/js/widget.min.js';fjs.parentNode.insertBefore(js,fjs);}}(document,'script','weatherwidget-io-js');
#                          </script>
#  </div>
#  </div><!-- /.dropdown -->
#  </li>
#  <li class="nav-absolute nav-absolute-secondary">
#  <a class="nav-clear nav-clear-darker logInBtn" href="https://www.okaz.com.sa/login">
#  <i class="fa fa-user"></i>
#  <span class="tablet-shown">تسجيل الدخول</span>
#  </a>
#  </li>
#  <li class="nav-search">
#  <a class="nav-clear js-panel-toggle" data-target="#modal-search" role="button">
#  <i class="fa fa-search"></i>
#  <i class="fa fa-close"></i>
#  </a>
#  </li><!-- /.nav-search -->
#  </ul>
#  </nav><!-- /.nav nav-utilities -->
#  </div><!-- /.nav-wrapper -->
#  </div><!-- /.header-content -->
#  </div><!-- /.shell -->
#  </header><!-- /.header -->
#  <div class="ajaxLoadedContent">
#  <!--CMS: 2047423-->
#  <!--NP: 891061-->
#  <!--ISOLD: 0-->
#  <!--OLD: 0-->
#  <!-- article-details.phtml -->
#  <div style="height:450px;"></div>
#  <div class="modal modal-article js-panel article-visible" data-hash="modal-article" id="modal-article">
#  <div class="shell shell-medium">
#  <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-article"></div>
#  <div class="modal-container">
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg"/>
#  </div>
#  <a class="modal-nav modal-prev" href="https://www.okaz.com.sa/sport/saudi/2047422">
#  <span>
#  <i class="icon-arrow-right" style="background-image: none;">
#  <svg viewbox="0 0 20.25808 37.41076" xmlns="http://www.w3.org/2000/svg">
#  <defs>
#  <style>.cls-1 {
#                                                  fill: none;
#                                                  stroke: #ccc;
#                                                  stroke-width: 2px;
#                                              }</style>
#  </defs>
#  <title>arrow-right</title>
#  <g data-name="Layer 2" id="Layer_2">
#  <g data-name="Layer 1" id="Layer_1-2">
#  <g data-name="Layer 2" id="Layer_2-2">
#  <g data-name="PART 201.fw-Page 201" id="PART_201.fw-Page_201">
#  <polyline class="cls-1" points="1.161 36.71 18.847 18.71 0.704 0.71"></polyline>
#  </g>
#  </g>
#  </g>
#  </g>
#  </svg>
#  </i>
#  </span>
#  </a>
#  <a class="modal-nav modal-next" href="https://www.okaz.com.sa/sport/saudi/2047437">
#  <span>
#  <i class="icon-arrow-left" style="background-image: none;">
#  <svg viewbox="0 0 20.2582 37.41076" xmlns="http://www.w3.org/2000/svg"><title>
#                                          arrow-left</title>
#  <g data-name="Layer 2" id="Layer_2">
#  <g data-name="PART%201.fw-Page%201" id="PART_201.fw-Page_201">
#  <polyline fill="none" points="19.554 0.71 1.411 18.71 19.097 36.71" stroke="#ccc" stroke-width="2"></polyline>
#  </g>
#  </g>
#  </svg>
#  </i>
#  </span>
#  </a>
#  <div class="modal-close modal-close-secondary-new js-panel-toggle js-panel-close mobile-hidden is-current" data-sectionlink="https://www.okaz.com.sa/sports" data-target="#modal-article">
#  </div>
#  <input id="cmsArticleId" type="hidden" value="2047423"/>
#  <div class="modal-inner">
#  <div class="modal-inner-content">
#  <div id="printThis">
#  <article class="article-main" data-title="الليث يقلبها على الفتح ويقفز للوصافة" data-url="https://www.okaz.com.sa/sport/saudi/2047423">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-header">
#  <script>
#  											googletag.cmd.push(function() { googletag.display('div-gpt-ad-header'); });
#  											</script>
#  </div>
#  </div>
#  <header class="article-head">
#  <div class="shell shell-secondary">
#  <h3 class="article-subtitle"></h3>
#  <!-- /.article-subtitle -->
#  <h1 class="autoHeight">الليث يقلبها على الفتح ويقفز للوصافة</h1>
#  <div class="article-meta">
#  <!-- <div class="show-for-mobile"></div> -->
#  <ul class="list-meta-items header-top show-for-desktop">
#  <li class="media_article_publish_time">
#  <p>
#  <span class="tag" style="background-color: #11e944 ; margin-bottom: 0px;color:#fff;">
#                                                          رياضة                                                    </span>
#                                                      السبت 7 نوفمبر 2020  19:56                                                </p>
#  </li>
#  <li>
#  <a style="cursor: default;">صالح الحربي (جدة) saleh_a_alharbi@</a>
#  </li>
#  <li>
#  <p>
#  <i class="fa fa-eye"></i>
#
#                                                      40                                                    <span class="hidden-xs">مشاهدة</span>
#  </p>
#  </li>
#  </ul><!-- /.list-meta-items -->
#  </div><!-- /.article-meta -->
#  </div><!-- /.shell shell-secondary -->
#  </header><!-- /.article-head -->
#  <div class="ads-preview" style="margin:10px auto;">
#  <div id="TopOkaz29">
#  <script>
#      window.googletag = window.googletag || {cmd: []};
#      googletag.cmd.push(function() {
#      googletag.defineSlot('/3387746/okaz_com_sa_news/top', [[360, 300], [336, 280], [728, 90], [300, 250], [320,100]], 'TopOkaz29').addService(googletag.pubads());
#      googletag.enableServices();
#      googletag.display('TopOkaz29');
#      });
#    </script>
#  </div> </div>
#  <div class="article-body">
#  <div class="shell shell-secondary">
#  <div class="article-inner">
#  <div class="article-content">
#  <div class="addthis_toolbox socials-secondary article-social">
#  <ul>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_facebook socials-facebook" href="javascript:void(0)">
#  <p>
#  <i class="fa fa-facebook"></i>
#  </p>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_twitter socials-twitter" href="javascript:void(0)">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="" href="javascript:void(0)">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_whatsapp socials-whatsapp" href="javascript:void(0)">
#  <i class="fa fa-whatsapp"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/article/2047423" class="addthis_button_telegram socials-telegram" href="javascript:void(0)">
#  <i class="fa fa-telegram"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_email socials-email" href="javascript:void(0)">
#  <i class="fa fa-envelope"></i>
#  </a>
#  </li>
#  <li>
#  <a class="printArticle">
#  <i class="fa fa-print"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials-secondary -->
#  <script type="text/javascript">
#                                                  var addthis_share = {
#                                                      url: "https://www.okaz.com.sa/sport/saudi/2047423",
#                                                      url_transforms: {
#                                                          shorten: {
#                                                              twitter: 'bitly',
#                                                              whatsapp: 'bitly',
#                                                              facebook: 'bitly',
#                                                              telegram: 'bitly',
#                                                              email: 'bitly'
#                                                          }
#                                                      },
#                                                      shorteners : {
#                                                          bitly : {}
#                                                      }
#                                                  }
#                                              </script>
#  <div class="article-entry">
#  <!-- single-image.phtml-->
#  <div class="article-entry">
#  <figure class="articleImage" id="lightgallery">
#  <div class="ratio">
#  <div class="itemLightGallery" data-src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg">
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: contain;object-position: center center;"/>
#  </div>
#  </div>
#  <a class="btn-popup popup-trigger multiple-trigger hidden-xs callLightGallery">
#  <i class="fa fa-expand"></i>
#  </a>
#  <figcaption></figcaption>
#  </figure>
#  <!-- <img class="img-responsive" style="max-width: 100%" width="100%"
#                               title="الليث يقلبها على الفتح ويقفز للوصافة"
#                               caption="" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg"> -->
#  <!--<p class="bodyText">
#
#  	</p> -->
#  <!-- /.list-tags -->
#  </div><!-- /.article-entry -->
#  <!-- Article Author name -->
#  <div class="article-actions-secondary">
#  <a id="shrinkText">-A</a>
#  <a id="enlargeText">+A</a>
#  </div><!-- /.article-actions-secondary -->
#  <div class="article-actions-secondary">
#  <a style="background: none;width: auto;cursor: default;">صالح الحربي (جدة) saleh_a_alharbi@</a>
#  </div>
#  <div class="bodyText">
#                                                      قلب فريق الشباب تأخره بهدف من أمام مضيفه الفتح إلى فوز مستحق بثلاثة أهداف لهدف، في اللقاء الذي جمع بينهما على استاد مدينة الأمير عبدالله بن جلوي، ضمن لقاءات جولة «لنلهم العالم بقمتنا» لدوري كأس الأمير محمد بن سلمان للمحترفين.<br/><br/>بدأ الشباب بهجمات متتالية وسط تحفظ دفاعي من الفتح الذي استغل هجمة مرتدة قادها جوستاف ليتحصل على ركلة جزاء تقدم لها سفيان بن دبكة ليحرز الهدف الأول للفتح (د:37).<!--mobileAd--><div class="ads-preview"><div id="leftsidebar3"><script>window.googletag = window.googletag || {cmd: []};googletag.cmd.push(function() {googletag.defineSlot('/3387746/okaz_com_sa_news/leftsidebar3', [[360, 300], [336, 280], [300, 250]],'leftsidebar3').addService(googletag.pubads());googletag.enableServices();googletag.display('leftsidebar3');});</script></div></div><br/><br/>وفي الشوط الثاني قلب الشباب الطاولة على الفتح وأحرز هدفين في خمس دقائق، وفي الوقت بدل الضائع أضاف الهدف الثالث، وجاءت الأهداف الثلاثة للشباب عن طريق كل من: تركي العمار (هدفين د:74، 90+6)، وفابيو مارتينز (د:78)، ومنح حكم اللقاء فيصل البلوي بطاقة حمراء للاعب الفتح حسن الحبيب (د:85)، وبعد 8 دقائق كوقت بدل ضائع أعلن الحكم نهاية اللقاء بفوز الشباب بهدفين لهدف.<br/><br/>وبهذه النتيجة قفز الشباب للمركز الثاني برصيد 10 نقاط، متساوياً مع المتصدر الهلال الذي يتفوق بفارق الأهداف، فيما تجمد رصيد الفتح عند 7 نقاط في المركز الخامس.<div class="clear"></div><br><div class="pagingWrap" style="display:none;"><a class="button grey prevBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=0" style="display:none;">&lt; Previous Page</a><a class="button grey nextBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=2" style="display:none;">Next Page &gt;</a></div> </br></div>
#  <div class="bodyTextToPrint"></div>
#  <ul class="list-tags">
#  </ul><!-- /.list-tags -->
#  </div><!-- /.article-entry -->
#  </div><!-- /.article-content -->
#  <aside class="article-aside">
#  <ul class="widgets-tertiary">
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-leftsidebar1">
#  <script>
#  																googletag.cmd.push(function() { googletag.display('div-gpt-ad-leftsidebar1'); });
#  																</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget widget-subscribe">
#  <!--<h4 class="widget-title">إشترك بالنشرة الإلكترونية</h4>-->
#  <!-- /.widget-title -->
#  <div class="subscribe">
#  <a href="https://www.okaz.com.sa/login#register">
#  <button class="btn form-btn">إشترك بالنشرة الإلكترونية</button>
#  </a>
#  <!--                                                            <form>
#                                                                                                                              <div class="subscribe-inner">
#                                                                                                                                  <label for="mail" class="hidden">البريد
#                                                                                                                                      الإلكتروني</label>
#
#                                                                                                                                  <input type="email" id="mail" name="mail" value=""
#                                                                                                                                         placeholder="البريد الإلكتروني"
#                                                                                                                                         class="field subscribe-field"/>
#
#                                                                                                                                  <input type="submit" value="إشترك"
#                                                                                                                                         class="btn-secondary subscribe-btn"
#                                                                                                                                         onclick="NewsLetterSubscribe()"/>
#                                                                                                                              </div>
#                                                                                                                              <div class="result-message"></div>
#                                                                                                                              <div class="SubscribeRecaptcha">
#                                                                                                                                  <div class="form-actions form-recaptcha">
#                                                                                                                                      <div class="clear"></div>
#                                                                                                                                      <div class="g-recaptcha"
#                                                                                                                                           id="recaptchaRegister"   data-sitekey="6LfxP70UAAAAAC0TVQ_oIZIrZVugmXY8s-asC312"></div>
#                                                                                                                                      <div class="hidden recaptchaText recaptchaTextPage">
#                                                                                                                                          الرمز خاطئ حاول مرة أخرى
#                                                                                                                                      </div>
#                                                                                                                                  </div>
#                                                                                                                              </div>
#                                                                                                                          </form>-->
#  </div><!-- /.subscribe -->
#  </li><!-- /.widget widget-subscribe -->
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-ajlan_bros">
#  <script>
#  															googletag.cmd.push(function() { googletag.display('div-gpt-ad-ajlan_bros'); });
#  															</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget widget-updates mobile-hidden widget-header">
#  <div class="widget-head">
#  <h4>أخبار شائعة</h4>
#  </div><!-- /.widget-head -->
#  <div class="widget-body">
#  <div class="update update-medium tablet-hidden">
#  <a class="ratio" href="https://www.okaz.com.sa/sport/saudi/2001328">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="عادل التويجري" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2019/12/18/1455901.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  <header class="update-head">
#  <h4 class="title-large">إيقاف الناقد الرياضي عادل التويجري</h4>
#  <!-- /.title-large -->
#  </header><!-- /.update-head -->
#  </a>
#  </div><!-- /.update update-medium tablet-hidden -->
#  <ul class="updates-secondary">
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2012826">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/02/29/1516676.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>وفاة «رضيع» حضر مباراة الفتح والوحدة</h6>
#  <span class="update-meta">
#                                                                                      السبت 29 فبراير 2020  20:11                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/international/2005434">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="المصارع لاباركا بعد سقوطه خارج الحلبة" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/01/14/1478929.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>وفاة المصارع «لاباركا» متاثرا بإصابته أثناء النزال</h6>
#  <span class="update-meta">
#                                                                                      الثلاثاء 14 يناير 2020  17:51                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2004255">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="العويران في أيامه الأخيرة" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/01/07/1472755.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>العويران في ذمة الله</h6>
#  <span class="update-meta">
#                                                                                      الثلاثاء 7 يناير 2020  12:27                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  </ul><!-- /.updates-secondary -->
#  </div><!-- /.widget-body -->
#  </li><!-- /.widget widget-updates mobile-hidden -->
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-leftsidebar2">
#  <script>
#  															googletag.cmd.push(function() { googletag.display('div-gpt-ad-leftsidebar2'); });
#  															</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget">
#  </li>
#  </ul><!-- /.widgets-tertiary -->
#  </aside><!-- /.article-aside -->
#  </div><!-- /.article-inner -->
#  </div><!-- /.shell shell-secondary -->
#  </div><!-- /.article-body -->
#  </article>
#  <!-- /.article-main -->
#  </div>
#  <div class="mobile-hidden">
#  <div class="shell shell-small">
#  <div class="ads-preview">
#  </div>
#  </div><!-- /.shell shell-small -->
#  </div><!-- /.banner modal-banner mobile-hidden -->
#  <footer class="modal-footer">
#  <div class="shell shell-secondary">
#  <h3>أخبار ذات صلة</h3>
#  <ul class="updates-inline widget-header">
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047437">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658740.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>النصر ينفجر في القادسية</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047422">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658625.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>«الراقي» يبطل مفاجأة «العين»</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047420">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658602.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>وفد تقييم دورة الألعاب 2030.. في الرياض</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047382">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/06/1658383.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>الاتحاد يخذل جماهيره بالتعادل مع رديف التعاون</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  </ul><!-- /.updates-inline -->
#  </div><!-- /.shell shell-secondary -->
#  </footer><!-- /.modal-footer -->
#  <div class="modal-actions mobile-shown mobile-shown-block">
#  <div class="banner banner-secondary">
#  </div><!-- /.banner banner-secondary -->
#  <a class="link-more btn-top go-top"></a>
#  </div><!-- /.modal-actions mobile-shown mobile-shown-block -->
#  </div>
#  </div><!-- /.modal-inner -->
#  </div><!-- /.modal-container -->
#  </div><!-- /.shell shell-medium -->
#  </div><!-- /.modal modal-article js-panel -->
#  <style>
#  	.stickyAdsBottom{
#  		width:100%;
#  		height:70px;
#  		position:fixed;
#  		z-index: 9999999999;
#  		right: 0;
#  		bottom: 0;
#  		display: none;
#  	}
#      @media (max-width: 767px) {
#          .bar-secondary.hide-bar-secondary{
#              bottom: 60px;
#              right: -62px;
#          }
#          .bar-secondary{
#              bottom: 60px;
#              right: -10px;
#          }
#          .bar-actions .btn-bordered{
#              border-right: 3px solid #ee3342;
#              border-bottom: none;
#          }
#      }
#  </style>
#  <script type="application/ld+json">
#      {
#      "@context": "http://schema.org",
#      "@type": "NewsArticle",
#      "mainEntityOfPage":{
#      "@type":"WebPage",
#      "@id":"2047423"
#      },
#      "headline": "الليث يقلبها على الفتح ويقفز للوصافة",
#      "image": {
#      "@type": "ImageObject",
#      "url": "https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg",
#      "height": 800,
#      "width": 800
#      },
#      "datePublished": "2020-11-07T19:56:28+03:00",
#      "dateModified": "2020-11-07T19:56:28+03:00",
#      "author": {
#      "@type": "Person",
#      "name": "صالح الحربي (جدة) saleh_a_alharbi@"
#      },
#      "publisher": {
#      "@type": "Organization",
#      "name": "okaz",
#      "logo": {
#      "@type": "ImageObject",
#      "url": "https://www.okaz.com.sa/themes/okazksa/images/new-okazlogo.png",
#      "width": 393,
#      "height": 108
#      }
#      },
#      "description": "الليث يقلبها على الفتح ويقفز للوصافة"
#      }
#  </script>
#  <div class="socialFixOuter hidden-xs">
#  <a class="socialFix" href="https://twitter.com/okaz_online" style="background-image: url(images/socialFix/twitter.jpg);background-color: #00aced;" target="_blank"></a>
#  <a class="socialFix" href="https://www.facebook.com/OKAZNEWS" style="background-image: url(images/socialFix/facebook.jpg);background-color: #3765a3;" target="_blank"></a>
#  <a class="socialFix" href="https://www.snapchat.com/add/Okaz1" style="background-image: url(images/socialFix/snapchat.jpg);background-color: #fffc00;" target="_blank"></a>
#  <a class="socialFix" href="https://instagram.com/okaznewspaper/" style="background-image: url(images/socialFix/instagram.jpg);background-color: #bebebe;" target="_blank"></a>
#  <a class="socialFix" href="/rss" style="background-image: url(images/socialFix/rss.jpg);background-color: #ff7b0a;" target="_blank"></a>
#  <a class="socialFix" href="https://www.youtube.com/user/okazonline" style="background-image: url(images/socialFix/youtube.jpg);background-color: #e41d2f" target="_blank"></a>
#  <a class="socialFix" href="https://telegram.me/okaz_sa" style="background-image: url(images/socialFix/telegram.png); background-color: #2299d6;"></a>
#  </div>
#  </div>
#  <script type="text/javascript">
#                              var HttpClient = function () {
#                                  this.get = function (aUrl, aCallback) {
#                                      var anHttpRequest = new XMLHttpRequest();
#                                      anHttpRequest.onreadystatechange = function () {
#                                          if (anHttpRequest.readyState == 4 && anHttpRequest.status == 200)
#                                              aCallback(anHttpRequest.responseText);
#                                      }
#
#                                      anHttpRequest.open("GET", aUrl, true);
#                                      anHttpRequest.send(null);
#                                  }
#                              }
#
#                              function incrementArticleVisitcount(articleId) {
#                                  var article_counter_url = "/ajax/article_count/" + articleId + "?ts=" + Date.now();
#                                  var client = new HttpClient();
#                                  client.get(article_counter_url, function (response) {
#                                      console.log(response);
#                                  });
#                              }
#
#                              //                var articleId = (document.getElementById('cmsArticleId'));
#                              //                if (articleId) {
#                              //                    incrementArticleVisitcount(articleId.value);
#                              //                }
#                              </script>
#  <footer class="footer" id="mainFooter">
#  <div class="footer-content">
#  <div class="shell">
#  <div class="footer-cols">
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div><!-- /.footer-cols -->
#  </div><!-- /.shell -->
#  </div><!-- /.footer-content -->
#  <div class="footer-bar">
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div><!-- /.shell -->
#  </div><!-- /.footer-bar -->
#  <!--<div class="newsPress">
#  	<span>Powered by <a href="http://layoutintl.com" target="_blank">NewsPress</a></span>
#  </div>-->
#  <input id="FOOTER_HEIGHT" type="hidden" value="">
#  </input></footer>
#  <script>
#                                  function EmbedScript() {
#                                      var _Impulser = window.parent.document.createElement('script');
#                                      _Impulser.type = 'text/javascript';
#                                      _Impulser.async = true;
#                                      _Impulser.src = ('https:' == window.parent.document.location.protocol ? 'https://' : 'http://') + 'impulse.forkcdn.com/impulse3/config/impulse.js';
#                                      var _scripter = window.parent.document.getElementsByTagName('script')[0];
#                                      _scripter.parentNode.insertBefore(_Impulser, _scripter);
#                                  }
#                                  ;
#                                  function inIframe() {
#                                      try {
#                                          return window.self !== window.top;
#                                      } catch (e) {
#                                          return true;
#                                      }
#                                  }
#                                  if (inIframe()) {
#                                      window.parent.$ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                      EmbedScript();
#                                  } else {
#                                      $ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                      EmbedScript();
#                                  }
#                              </script>
#  <!-- the arrows for big-page -->
#  <script src="images/icons/grunticon.loader.js" type="text/javascript"></script>
#  <script>
#                                  grunticon(["images/icons/icons.data.svg.css", "images/icons/icons.data.png.css", "images/icons/icons.fallback.css"], grunticon.svgLoadedCallback);
#                              </script>
#  <!-- the arrows for big-page -->
#  <script async="" rel="preconnect" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
#  <!-- Fall back to a local copy of jQuery if the CDN fails-->
#  <noscript><script src="https://www.okaz.com.sa/js/jquery.min.js"></script></noscript>
#  <script defer="" src="https://www.okaz.com.sa/themes/okazksa/js/script-one.js?v=0.73"></script><!--515kb-->
#  <!-- Go to www.addthis.com/dashboard to customize your tools replace  async="async" by defer -->
#  <script defer="" rel="preconnect" src="//s7.addthis.com/js/300/addthis_widget.js&amp;async=1#pubid=ra-57d7a6b3b67f6bef" type="text/javascript"></script>
#  <!--Vibe_okaz-->
#  <script async="" id="_forkIAVScript" src="//vibecdn.forkcdn.com/Inarticle/iav.js?publisher=okaz"></script>
#  <noscript><a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a97c95f6&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4210&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a97c95f6"/></a></noscript>
#  <noscript><a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a87267e0&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4211&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a87267e0"/></a></noscript>
#  <!--Vibe_okaz-->
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg">
#  </img></div>
#  <script>
#  								$(function(){
#  									$(window).scroll(function(){
#  										if($(window).scrollTop() > 100){
#  											$(".stickyAdsBottom").css("display","block");
#  										}else{
#  											$(".stickyAdsBottom").css("display","none");
#  										}
#  									});
# ...
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div><!-- /.footer-cols -->
#  </div>,
#  <div class="footer-cols">
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div>,
#  <div class="footer-bar">
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div><!-- /.shell -->
#  </div>,
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div>,
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div>,
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>,
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>,
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>,
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div>,
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg">
#  </img></div>,
#  <div>
#  <!-- Desktop+Mobile Banner -->
#  <div id="div-gpt-ad-1x1">
#  <script>
#  									googletag.cmd.push(function() { googletag.display('div-gpt-ad-1x1'); });
#  								  </script>
#  </div>
#  </div>,
#  <div id="div-gpt-ad-1x1">
#  <script>
#  									googletag.cmd.push(function() { googletag.display('div-gpt-ad-1x1'); });
#  								  </script>
#  </div>]

# %%
print(soup.get_text())
# Out:
# الليث يقلبها على الفتح ويقفز للوصافة - أخبار السعودية | صحيفة عكاظ
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# خبر عاجل
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ابحث
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# ابحث
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 الرئيسية
#
#
#
#
#
#
#                                 أخبار
#
#
#
#
#
#
#                                 رياضة
#
#
#
#
#
#
#                                 اقتصاد
#
#
#
#
#
#
#                                 ثقافة و فن
#
#
#
#
#
#
#                                 منوعات
#
#
#
#
#
#
#                                 ملتيميديا
#
#
#
#
#
#
#                                 مقالات
#
#
#
#
#
#                         المزيد
#
#
#
#
#
#
# سعوديات
#
#
# أزياء
#
#
# سياحة
#
#
# الناس
#
#
# تحقيقات
#
#
# تكنولوجيا
#
#
# صوت المواطن
#
#
# ألعاب
#
#
# زوايا متخصصة
#
#
# سوق عكاظ
#
#
# تصفح عدد اليوم
#
#
#
#
#
#
#
#
#
#
#
#
#
#                         المزيد
#
#
#
#
# سعوديات
#
#
# أزياء
#
#
# سياحة
#
#
# الناس
#
#
# تحقيقات
#
#
# تكنولوجيا
#
#
# صوت المواطن
#
#
# ألعاب
#
#
# زوايا متخصصة
#
#
# سوق عكاظ
#
#
#
#
#
#
#
# إرسال مواد أو صور
#
#
#
#
#
#
#
#
#
#
# طقس السعودية
#
#
#
#
#
#
#
# تسجيل الدخول
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# arrow-right
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                         arrow-left
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# الليث يقلبها على الفتح ويقفز للوصافة
#
#
#
#
#
#
#                                                         رياضة
#                                                     السبت 7 نوفمبر 2020  19:56
#
#
# صالح الحربي (جدة) saleh_a_alharbi@
#
#
#
#
#
#                                                     40                                                    مشاهدة
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# -A
# +A
#
#
# صالح الحربي (جدة) saleh_a_alharbi@
#
#
#                                                     قلب فريق الشباب تأخره بهدف من أمام مضيفه الفتح إلى فوز مستحق بثلاثة أهداف لهدف، في اللقاء الذي جمع بينهما على استاد مدينة الأمير عبدالله بن جلوي، ضمن لقاءات جولة «لنلهم العالم بقمتنا» لدوري كأس الأمير محمد بن سلمان للمحترفين.بدأ الشباب بهجمات متتالية وسط تحفظ دفاعي من الفتح الذي استغل هجمة مرتدة قادها جوستاف ليتحصل على ركلة جزاء تقدم لها سفيان بن دبكة ليحرز الهدف الأول للفتح (د:37).وفي الشوط الثاني قلب الشباب الطاولة على الفتح وأحرز هدفين في خمس دقائق، وفي الوقت بدل الضائع أضاف الهدف الثالث، وجاءت الأهداف الثلاثة للشباب عن طريق كل من: تركي العمار (هدفين د:74، 90+6)، وفابيو مارتينز (د:78)، ومنح حكم اللقاء فيصل البلوي بطاقة حمراء للاعب الفتح حسن الحبيب (د:85)، وبعد 8 دقائق كوقت بدل ضائع أعلن الحكم نهاية اللقاء بفوز الشباب بهدفين لهدف.وبهذه النتيجة قفز الشباب للمركز الثاني برصيد 10 نقاط، متساوياً مع المتصدر الهلال الذي يتفوق بفارق الأهداف، فيما تجمد رصيد الفتح عند 7 نقاط في المركز الخامس.< Previous PageNext Page >
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# إشترك بالنشرة الإلكترونية
#
#
#
#
#
#
#
#
#
#
#
#
#
# أخبار شائعة
#
#
#
#
#
#
#
#
#
#
#
# إيقاف الناقد الرياضي عادل التويجري
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# وفاة «رضيع» حضر مباراة الفتح والوحدة
#
#                                                                                     السبت 29 فبراير 2020  20:11
#
#
#
#
#
#
#
#
#
#
#
#
#
# وفاة المصارع «لاباركا» متاثرا بإصابته أثناء النزال
#
#                                                                                     الثلاثاء 14 يناير 2020  17:51
#
#
#
#
#
#
#
#
#
#
#
#
#
# العويران في ذمة الله
#
#                                                                                     الثلاثاء 7 يناير 2020  12:27
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# أخبار ذات صلة
#
#
#
#
#
#
#
#
#
#
#
# رياضة
#
# النصر ينفجر في القادسية
#
#
#
#
#
#
#
#
#
#
#
#
#
# رياضة
#
# «الراقي» يبطل مفاجأة «العين»
#
#
#
#
#
#
#
#
#
#
#
#
#
# رياضة
#
# وفد تقييم دورة الألعاب 2030.. في الرياض
#
#
#
#
#
#
#
#
#
#
#
#
#
# رياضة
#
# الاتحاد يخذل جماهيره بالتعادل مع رديف التعاون
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# أخبار
#
#
#
# محليات
#
#
# سياسة
#
#
#
#
#
# رياضة
#
#
#
# السعودية
#
#
# العربية
#
#
# الدولية
#
#
# العاب منوعة
#
#
# مقابلات خاصة
#
#
#
#
#
# اقتصاد
#
#
#
# السعودية
#
#
# العربية
#
#
# الدولية
#
#
#
#
#
# ثقافة و فن
#
#
#
# فن
#
#
# ثقافة
#
#
# اخرى
#
#
#
#
#
# سوق عكاظ
#
#
#
# عقار
#
#
# حراج
#
#
#
#
#
# مقالات
#
#
#
# كتاب الرأي
#
#
# نبض القراء
#
#
#
#
# المزيد
#
#
# سعوديات
#
#
# أزياء
#
#
# سياحة
#
#
# احوال الناس
#
#
# تحقيقات
#
#
# تكنولوجيا
#
#
# صوت المواطن
#
#
# حالة الطقس
#
#
# منوعات
#
#
# ألعاب
#
#
# زوايا متخصصة
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# الشروط والأحكام
#
#
# حول المؤسسة
#
#
# إدارة التحرير
#
#
#
# للإعلان
#
#
# إتصل بنا
#
#
#                     حقوق الملكية ©   عكاظ 2020. جميع الحقوق محفوظة

# %%
soup.find_all('div')
# Out:
# [<div id="fb-root"></div>,
#  <div class="modal modal-edit js-panel" data-hash="modal" id="modal"> </div>,
#  <div class="modal modal-edit js-panel" data-hash="disclaimer" id="disclaimer"> </div>,
#  <div class="bar-alert">
#  <div class="shell">
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div><!-- /.bar-body -->
#  </div><!-- /.shell -->
#  </div>,
#  <div class="shell">
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div><!-- /.bar-body -->
#  </div>,
#  <div class="bar-body">
#  <span class="bar-aside">خبر عاجل</span>
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div><!-- /.bar-content -->
#  <a class="bar-close">
#  <i class="fa fa-close"></i>
#  </a>
#  </div>,
#  <div class="bar-content" id="breakingNews">
#  <ul>
#  </ul>
#  </div>,
#  <div class="wrapper">
#  <div class="bar" id="mainHeader">
#  <div class="shell">
#  <div class="bar-body">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <!--<div class="beta-site"></div>-->
#  <a class="btn-menu">
#  <span></span>
#  </a>
#  <div class="searchMobileBtn search-btn submitSearch visible-xs-block">
#  <i class="fa fa-search"></i>
#  </div>
#  <div class="logInBtnMobile visible-xs-block">
#  <a href="https://www.okaz.com.sa/login">
#  <i class="fa fa-user"></i>
#  </a>
#  </div>
#  </div><!-- /.bar-body -->
#  </div><!-- /.shell -->
#  <div class="search searchMobile visible-xs-block">
#  <label class="hidden" for="q">ابحث</label>
#  <input class="field search-field query" placeholder="ابحث" type="search"/>
#  </div>
#  </div><!-- /.bar -->
#  <header class="header">
#  <div class="shell">
#  <!--menu.tpl-->
#  <div class="header-content">
#  <!--    <a class="btn-menu">
#          <span class="close-menu"></span>
#      </a>-->
#  <div class="nav-wrapper">
#  <nav class="nav nav-main">
#  <div class="modal modal-search js-panel" data-hash="modal-search" id="modal-search">
#  <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-search"></div><!-- /.modal-overlay js-panel-toggle js-panel-close -->
#  <div class="modal-container">
#  <div class="search">
#  <label class="hidden" for="q">ابحث</label>
#  <input class="field search-field query" placeholder="ابحث" type="search">
#  <button class="search-btn submitSearch">
#  <i class="fa fa-search"></i>
#  </button>
#  </input></div><!-- /.search -->
#  </div><!-- /.modal-container -->
#  </div><!-- /.modal modal-search js-panel -->
#  <ul>
#  <li class="nav-logo mobile-hidden">
#  <a class="emblem" href="https://www.okaz.com.sa/"></a>
#  </li><!-- /.nav-logo -->
#  <li class="nav-white nav-home" style="border-color: #fc6142;background-color: #fc6142">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/" style="border-color: ">
#  <span>
#                                  الرئيسية                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #00dac1;background-color: #00dac1">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/news" style="border-color: #00dac1">
#  <span>
#                                  أخبار                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #11e944;background-color: #11e944">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/sports" style="border-color: #11e944">
#  <span>
#                                  رياضة                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #40d1f2;background-color: #40d1f2">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/economy" style="border-color: #40d1f2">
#  <span>
#                                  اقتصاد                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #b156db;background-color: #b156db">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/culture" style="border-color: #b156db">
#  <span>
#                                  ثقافة و فن                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #ff896b;background-color: #ff896b">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/variety" style="border-color: #ff896b">
#  <span>
#                                  منوعات                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #ffc505;background-color: #ffc505">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/media/latest" style="border-color: #ffc505">
#  <span>
#                                  ملتيميديا                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="" style="border-color: #b07564;background-color: #b07564">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/articles" style="border-color: #b07564">
#  <span>
#                                  مقالات                            </span>
#  </a>
#  <line style="background-color: "></line>
#  </li>
#  <li class="has-dropdown mobile-shown">
#  <a class="open" style="border-color: #6b7e89;position: relative;">
#                          المزيد
#
#                          <i class="fa fa-chevron-down tablet-shown"></i>
#  </a>
#  <div class="dropdown">
#  <ul>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">الناس</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  <li>
#  <a class="ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </li>
#  <li>
#  <a class="animated" href="https://www.okaz.com.sa/digital">تصفح عدد اليوم</a>
#  </li>
#  <!--to fix ios mobile hiden menu we add 2 empty li-->
#  <li>   </li>
#  <li>     </li>
#  </ul>
#  </div><!-- /.dropdown -->
#  </li><!-- /.has-dropdown -->
#  </ul>
#  </nav><!-- /.nav nav-main -->
#  <nav class="nav nav-utilities">
#  <ul>
#  <li class="has-dropdown mobile-hidden grey">
#  <a>
#                          المزيد    <i class="fa fa-chevron-down"></i>
#  </a>
#  <div class="dropdown">
#  <ul>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/people-situations">الناس</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  <li class="">
#  <a class="menuText ajax_page_load animated" href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </li>
#  </ul>
#  </div><!-- /.dropdown -->
#  </li><!-- /.has-dropdown -->
#  <li class="nav-absolute">
#  <a class="nav-clear" href="../../add-article">
#  <i class="fa fa-camera"></i>
#  <span class="tablet-shown">إرسال مواد أو صور</span>
#  </a>
#  </li>
#  <li class="nav-absolute" id="weather">
#  <a href="../../weather">
#  <!--						<span class="nav-link-secondary tablet-shown">الطقس</span>
#                          <img id="weatherImg" src="" alt="" >
#                          <span id="temperature">الطقس</span>-->
#  <span class="weather-svgicon" id="temperature"></span>
#  </a>
#  <div class="dropdown">
#  <div class="weatherWidget">
#  <!--<iframe src="http://widgets.arabiaweather.com/getselectwidget/344?headcolor=undefined&extracolor=undefined&textcolor=undefined&daycolor=undefined&nightcolor=undefined&bgcolor=%23dad2ba&font_type=Arial&temperatureUnit=C&language_type=ar&location_ar_name=%D8%A7%D9%84%D8%B1%D9%8A%D8%A7%D8%B6%20&location_en_name=Riyadh&ifBackground=true&iframe_width=300&" width="300" frameborder="0" height="250" style="box-shadow:0px 1px 5px -1px rgba(0,0,0,0.8);"></iframe>-->
#  <a class="weatherwidget-io" data-label_1="السعودية" data-label_2="الطقس" data-theme="original" href="https://forecast7.com/ar/23d8945d08/saudi-arabia/" style="width: 320px;">طقس السعودية</a>
#  <script>
#                          !function(d,s,id){var js,fjs=d.getElementsByTagName(s)[0];if(!d.getElementById(id)){js=d.createElement(s);js.id=id;js.src='https://weatherwidget.io/js/widget.min.js';fjs.parentNode.insertBefore(js,fjs);}}(document,'script','weatherwidget-io-js');
#                          </script>
#  </div>
#  </div><!-- /.dropdown -->
#  </li>
#  <li class="nav-absolute nav-absolute-secondary">
#  <a class="nav-clear nav-clear-darker logInBtn" href="https://www.okaz.com.sa/login">
#  <i class="fa fa-user"></i>
#  <span class="tablet-shown">تسجيل الدخول</span>
#  </a>
#  </li>
#  <li class="nav-search">
#  <a class="nav-clear js-panel-toggle" data-target="#modal-search" role="button">
#  <i class="fa fa-search"></i>
#  <i class="fa fa-close"></i>
#  </a>
#  </li><!-- /.nav-search -->
#  </ul>
#  </nav><!-- /.nav nav-utilities -->
#  </div><!-- /.nav-wrapper -->
#  </div><!-- /.header-content -->
#  </div><!-- /.shell -->
#  </header><!-- /.header -->
#  <div class="ajaxLoadedContent">
#  <!--CMS: 2047423-->
#  <!--NP: 891061-->
#  <!--ISOLD: 0-->
#  <!--OLD: 0-->
#  <!-- article-details.phtml -->
#  <div style="height:450px;"></div>
#  <div class="modal modal-article js-panel article-visible" data-hash="modal-article" id="modal-article">
#  <div class="shell shell-medium">
#  <div class="modal-overlay js-panel-toggle js-panel-close" data-target="#modal-article"></div>
#  <div class="modal-container">
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg"/>
#  </div>
#  <a class="modal-nav modal-prev" href="https://www.okaz.com.sa/sport/saudi/2047422">
#  <span>
#  <i class="icon-arrow-right" style="background-image: none;">
#  <svg viewbox="0 0 20.25808 37.41076" xmlns="http://www.w3.org/2000/svg">
#  <defs>
#  <style>.cls-1 {
#                                                  fill: none;
#                                                  stroke: #ccc;
#                                                  stroke-width: 2px;
#                                              }</style>
#  </defs>
#  <title>arrow-right</title>
#  <g data-name="Layer 2" id="Layer_2">
#  <g data-name="Layer 1" id="Layer_1-2">
#  <g data-name="Layer 2" id="Layer_2-2">
#  <g data-name="PART 201.fw-Page 201" id="PART_201.fw-Page_201">
#  <polyline class="cls-1" points="1.161 36.71 18.847 18.71 0.704 0.71"></polyline>
#  </g>
#  </g>
#  </g>
#  </g>
#  </svg>
#  </i>
#  </span>
#  </a>
#  <a class="modal-nav modal-next" href="https://www.okaz.com.sa/sport/saudi/2047437">
#  <span>
#  <i class="icon-arrow-left" style="background-image: none;">
#  <svg viewbox="0 0 20.2582 37.41076" xmlns="http://www.w3.org/2000/svg"><title>
#                                          arrow-left</title>
#  <g data-name="Layer 2" id="Layer_2">
#  <g data-name="PART%201.fw-Page%201" id="PART_201.fw-Page_201">
#  <polyline fill="none" points="19.554 0.71 1.411 18.71 19.097 36.71" stroke="#ccc" stroke-width="2"></polyline>
#  </g>
#  </g>
#  </svg>
#  </i>
#  </span>
#  </a>
#  <div class="modal-close modal-close-secondary-new js-panel-toggle js-panel-close mobile-hidden is-current" data-sectionlink="https://www.okaz.com.sa/sports" data-target="#modal-article">
#  </div>
#  <input id="cmsArticleId" type="hidden" value="2047423"/>
#  <div class="modal-inner">
#  <div class="modal-inner-content">
#  <div id="printThis">
#  <article class="article-main" data-title="الليث يقلبها على الفتح ويقفز للوصافة" data-url="https://www.okaz.com.sa/sport/saudi/2047423">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-header">
#  <script>
#  											googletag.cmd.push(function() { googletag.display('div-gpt-ad-header'); });
#  											</script>
#  </div>
#  </div>
#  <header class="article-head">
#  <div class="shell shell-secondary">
#  <h3 class="article-subtitle"></h3>
#  <!-- /.article-subtitle -->
#  <h1 class="autoHeight">الليث يقلبها على الفتح ويقفز للوصافة</h1>
#  <div class="article-meta">
#  <!-- <div class="show-for-mobile"></div> -->
#  <ul class="list-meta-items header-top show-for-desktop">
#  <li class="media_article_publish_time">
#  <p>
#  <span class="tag" style="background-color: #11e944 ; margin-bottom: 0px;color:#fff;">
#                                                          رياضة                                                    </span>
#                                                      السبت 7 نوفمبر 2020  19:56                                                </p>
#  </li>
#  <li>
#  <a style="cursor: default;">صالح الحربي (جدة) saleh_a_alharbi@</a>
#  </li>
#  <li>
#  <p>
#  <i class="fa fa-eye"></i>
#
#                                                      40                                                    <span class="hidden-xs">مشاهدة</span>
#  </p>
#  </li>
#  </ul><!-- /.list-meta-items -->
#  </div><!-- /.article-meta -->
#  </div><!-- /.shell shell-secondary -->
#  </header><!-- /.article-head -->
#  <div class="ads-preview" style="margin:10px auto;">
#  <div id="TopOkaz29">
#  <script>
#      window.googletag = window.googletag || {cmd: []};
#      googletag.cmd.push(function() {
#      googletag.defineSlot('/3387746/okaz_com_sa_news/top', [[360, 300], [336, 280], [728, 90], [300, 250], [320,100]], 'TopOkaz29').addService(googletag.pubads());
#      googletag.enableServices();
#      googletag.display('TopOkaz29');
#      });
#    </script>
#  </div> </div>
#  <div class="article-body">
#  <div class="shell shell-secondary">
#  <div class="article-inner">
#  <div class="article-content">
#  <div class="addthis_toolbox socials-secondary article-social">
#  <ul>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_facebook socials-facebook" href="javascript:void(0)">
#  <p>
#  <i class="fa fa-facebook"></i>
#  </p>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_twitter socials-twitter" href="javascript:void(0)">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="" href="javascript:void(0)">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_whatsapp socials-whatsapp" href="javascript:void(0)">
#  <i class="fa fa-whatsapp"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/article/2047423" class="addthis_button_telegram socials-telegram" href="javascript:void(0)">
#  <i class="fa fa-telegram"></i>
#  </a>
#  </li>
#  <li>
#  <a addthis:media="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" addthis:title="الليث يقلبها على الفتح ويقفز للوصافة" addthis:url="https://www.okaz.com.sa/sport/saudi/2047423" class="addthis_button_email socials-email" href="javascript:void(0)">
#  <i class="fa fa-envelope"></i>
#  </a>
#  </li>
#  <li>
#  <a class="printArticle">
#  <i class="fa fa-print"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials-secondary -->
#  <script type="text/javascript">
#                                                  var addthis_share = {
#                                                      url: "https://www.okaz.com.sa/sport/saudi/2047423",
#                                                      url_transforms: {
#                                                          shorten: {
#                                                              twitter: 'bitly',
#                                                              whatsapp: 'bitly',
#                                                              facebook: 'bitly',
#                                                              telegram: 'bitly',
#                                                              email: 'bitly'
#                                                          }
#                                                      },
#                                                      shorteners : {
#                                                          bitly : {}
#                                                      }
#                                                  }
#                                              </script>
#  <div class="article-entry">
#  <!-- single-image.phtml-->
#  <div class="article-entry">
#  <figure class="articleImage" id="lightgallery">
#  <div class="ratio">
#  <div class="itemLightGallery" data-src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg">
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: contain;object-position: center center;"/>
#  </div>
#  </div>
#  <a class="btn-popup popup-trigger multiple-trigger hidden-xs callLightGallery">
#  <i class="fa fa-expand"></i>
#  </a>
#  <figcaption></figcaption>
#  </figure>
#  <!-- <img class="img-responsive" style="max-width: 100%" width="100%"
#                               title="الليث يقلبها على الفتح ويقفز للوصافة"
#                               caption="" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg"> -->
#  <!--<p class="bodyText">
#
#  	</p> -->
#  <!-- /.list-tags -->
#  </div><!-- /.article-entry -->
#  <!-- Article Author name -->
#  <div class="article-actions-secondary">
#  <a id="shrinkText">-A</a>
#  <a id="enlargeText">+A</a>
#  </div><!-- /.article-actions-secondary -->
#  <div class="article-actions-secondary">
#  <a style="background: none;width: auto;cursor: default;">صالح الحربي (جدة) saleh_a_alharbi@</a>
#  </div>
#  <div class="bodyText">
#                                                      قلب فريق الشباب تأخره بهدف من أمام مضيفه الفتح إلى فوز مستحق بثلاثة أهداف لهدف، في اللقاء الذي جمع بينهما على استاد مدينة الأمير عبدالله بن جلوي، ضمن لقاءات جولة «لنلهم العالم بقمتنا» لدوري كأس الأمير محمد بن سلمان للمحترفين.<br/><br/>بدأ الشباب بهجمات متتالية وسط تحفظ دفاعي من الفتح الذي استغل هجمة مرتدة قادها جوستاف ليتحصل على ركلة جزاء تقدم لها سفيان بن دبكة ليحرز الهدف الأول للفتح (د:37).<!--mobileAd--><div class="ads-preview"><div id="leftsidebar3"><script>window.googletag = window.googletag || {cmd: []};googletag.cmd.push(function() {googletag.defineSlot('/3387746/okaz_com_sa_news/leftsidebar3', [[360, 300], [336, 280], [300, 250]],'leftsidebar3').addService(googletag.pubads());googletag.enableServices();googletag.display('leftsidebar3');});</script></div></div><br/><br/>وفي الشوط الثاني قلب الشباب الطاولة على الفتح وأحرز هدفين في خمس دقائق، وفي الوقت بدل الضائع أضاف الهدف الثالث، وجاءت الأهداف الثلاثة للشباب عن طريق كل من: تركي العمار (هدفين د:74، 90+6)، وفابيو مارتينز (د:78)، ومنح حكم اللقاء فيصل البلوي بطاقة حمراء للاعب الفتح حسن الحبيب (د:85)، وبعد 8 دقائق كوقت بدل ضائع أعلن الحكم نهاية اللقاء بفوز الشباب بهدفين لهدف.<br/><br/>وبهذه النتيجة قفز الشباب للمركز الثاني برصيد 10 نقاط، متساوياً مع المتصدر الهلال الذي يتفوق بفارق الأهداف، فيما تجمد رصيد الفتح عند 7 نقاط في المركز الخامس.<div class="clear"></div><br><div class="pagingWrap" style="display:none;"><a class="button grey prevBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=0" style="display:none;">&lt; Previous Page</a><a class="button grey nextBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=2" style="display:none;">Next Page &gt;</a></div> </br></div>
#  <div class="bodyTextToPrint"></div>
#  <ul class="list-tags">
#  </ul><!-- /.list-tags -->
#  </div><!-- /.article-entry -->
#  </div><!-- /.article-content -->
#  <aside class="article-aside">
#  <ul class="widgets-tertiary">
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-leftsidebar1">
#  <script>
#  																googletag.cmd.push(function() { googletag.display('div-gpt-ad-leftsidebar1'); });
#  																</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget widget-subscribe">
#  <!--<h4 class="widget-title">إشترك بالنشرة الإلكترونية</h4>-->
#  <!-- /.widget-title -->
#  <div class="subscribe">
#  <a href="https://www.okaz.com.sa/login#register">
#  <button class="btn form-btn">إشترك بالنشرة الإلكترونية</button>
#  </a>
#  <!--                                                            <form>
#                                                                                                                              <div class="subscribe-inner">
#                                                                                                                                  <label for="mail" class="hidden">البريد
#                                                                                                                                      الإلكتروني</label>
#
#                                                                                                                                  <input type="email" id="mail" name="mail" value=""
#                                                                                                                                         placeholder="البريد الإلكتروني"
#                                                                                                                                         class="field subscribe-field"/>
#
#                                                                                                                                  <input type="submit" value="إشترك"
#                                                                                                                                         class="btn-secondary subscribe-btn"
#                                                                                                                                         onclick="NewsLetterSubscribe()"/>
#                                                                                                                              </div>
#                                                                                                                              <div class="result-message"></div>
#                                                                                                                              <div class="SubscribeRecaptcha">
#                                                                                                                                  <div class="form-actions form-recaptcha">
#                                                                                                                                      <div class="clear"></div>
#                                                                                                                                      <div class="g-recaptcha"
#                                                                                                                                           id="recaptchaRegister"   data-sitekey="6LfxP70UAAAAAC0TVQ_oIZIrZVugmXY8s-asC312"></div>
#                                                                                                                                      <div class="hidden recaptchaText recaptchaTextPage">
#                                                                                                                                          الرمز خاطئ حاول مرة أخرى
#                                                                                                                                      </div>
#                                                                                                                                  </div>
#                                                                                                                              </div>
#                                                                                                                          </form>-->
#  </div><!-- /.subscribe -->
#  </li><!-- /.widget widget-subscribe -->
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-ajlan_bros">
#  <script>
#  															googletag.cmd.push(function() { googletag.display('div-gpt-ad-ajlan_bros'); });
#  															</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget widget-updates mobile-hidden widget-header">
#  <div class="widget-head">
#  <h4>أخبار شائعة</h4>
#  </div><!-- /.widget-head -->
#  <div class="widget-body">
#  <div class="update update-medium tablet-hidden">
#  <a class="ratio" href="https://www.okaz.com.sa/sport/saudi/2001328">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="عادل التويجري" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2019/12/18/1455901.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  <header class="update-head">
#  <h4 class="title-large">إيقاف الناقد الرياضي عادل التويجري</h4>
#  <!-- /.title-large -->
#  </header><!-- /.update-head -->
#  </a>
#  </div><!-- /.update update-medium tablet-hidden -->
#  <ul class="updates-secondary">
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2012826">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/02/29/1516676.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>وفاة «رضيع» حضر مباراة الفتح والوحدة</h6>
#  <span class="update-meta">
#                                                                                      السبت 29 فبراير 2020  20:11                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/international/2005434">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="المصارع لاباركا بعد سقوطه خارج الحلبة" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/01/14/1478929.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>وفاة المصارع «لاباركا» متاثرا بإصابته أثناء النزال</h6>
#  <span class="update-meta">
#                                                                                      الثلاثاء 14 يناير 2020  17:51                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  <li class="update-small">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2004255">
#  <figure class="update-image" style="height: 58px;">
#  <div class="ratio">
#  <div>
#  <img alt="العويران في أيامه الأخيرة" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/01/07/1472755.jpg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  </figure><!-- /.update-image -->
#  <div class="update-content">
#  <h6>العويران في ذمة الله</h6>
#  <span class="update-meta">
#                                                                                      الثلاثاء 7 يناير 2020  12:27                                                                                </span>
#  </div><!-- /.update-content -->
#  </a>
#  </li><!-- /.update-small -->
#  </ul><!-- /.updates-secondary -->
#  </div><!-- /.widget-body -->
#  </li><!-- /.widget widget-updates mobile-hidden -->
#  <li class="widget">
#  <div class="ads-preview">
#  <div id="div-gpt-ad-leftsidebar2">
#  <script>
#  															googletag.cmd.push(function() { googletag.display('div-gpt-ad-leftsidebar2'); });
#  															</script>
#  </div>
#  </div>
#  </li>
#  <li class="widget">
#  </li>
#  </ul><!-- /.widgets-tertiary -->
#  </aside><!-- /.article-aside -->
#  </div><!-- /.article-inner -->
#  </div><!-- /.shell shell-secondary -->
#  </div><!-- /.article-body -->
#  </article>
#  <!-- /.article-main -->
#  </div>
#  <div class="mobile-hidden">
#  <div class="shell shell-small">
#  <div class="ads-preview">
#  </div>
#  </div><!-- /.shell shell-small -->
#  </div><!-- /.banner modal-banner mobile-hidden -->
#  <footer class="modal-footer">
#  <div class="shell shell-secondary">
#  <h3>أخبار ذات صلة</h3>
#  <ul class="updates-inline widget-header">
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047437">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658740.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>النصر ينفجر في القادسية</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047422">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658625.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>«الراقي» يبطل مفاجأة «العين»</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047420">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/07/1658602.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>وفد تقييم دورة الألعاب 2030.. في الرياض</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  <li class="update update-separated">
#  <a class="" href="https://www.okaz.com.sa/sport/saudi/2047382">
#  <div class="ratio">
#  <div>
#  <figure class="update-image">
#  </figure>
#  <!-- /.update-image -->
#  <img alt="" onerror="this.src='images/no-image.png'" src="https://www.okaz.com.sa/uploads/images/2020/11/06/1658383.jpeg" style="position: absolute;height: 100%;width: 100%;object-fit: cover;object-position: center center;"/>
#  </div>
#  </div>
#  <span class="update-tag update-tag-orange update-tag-absolute" style="background-color: #11e944;">رياضة</span>
#  <header class="update-head">
#  <h6>الاتحاد يخذل جماهيره بالتعادل مع رديف التعاون</h6>
#  </header><!-- /.update-head -->
#  </a>
#  </li><!-- /.update update-separated -->
#  </ul><!-- /.updates-inline -->
#  </div><!-- /.shell shell-secondary -->
#  </footer><!-- /.modal-footer -->
#  <div class="modal-actions mobile-shown mobile-shown-block">
#  <div class="banner banner-secondary">
#  </div><!-- /.banner banner-secondary -->
#  <a class="link-more btn-top go-top"></a>
#  </div><!-- /.modal-actions mobile-shown mobile-shown-block -->
#  </div>
#  </div><!-- /.modal-inner -->
#  </div><!-- /.modal-container -->
#  </div><!-- /.shell shell-medium -->
#  </div><!-- /.modal modal-article js-panel -->
#  <style>
#  	.stickyAdsBottom{
#  		width:100%;
#  		height:70px;
#  		position:fixed;
#  		z-index: 9999999999;
#  		right: 0;
#  		bottom: 0;
#  		display: none;
#  	}
#      @media (max-width: 767px) {
#          .bar-secondary.hide-bar-secondary{
#              bottom: 60px;
#              right: -62px;
#          }
#          .bar-secondary{
#              bottom: 60px;
#              right: -10px;
#          }
#          .bar-actions .btn-bordered{
#              border-right: 3px solid #ee3342;
#              border-bottom: none;
#          }
#      }
#  </style>
#  <script type="application/ld+json">
#      {
#      "@context": "http://schema.org",
#      "@type": "NewsArticle",
#      "mainEntityOfPage":{
#      "@type":"WebPage",
#      "@id":"2047423"
#      },
#      "headline": "الليث يقلبها على الفتح ويقفز للوصافة",
#      "image": {
#      "@type": "ImageObject",
#      "url": "https://www.okaz.com.sa/uploads/images/2020/11/07/1658627.jpeg",
#      "height": 800,
#      "width": 800
#      },
#      "datePublished": "2020-11-07T19:56:28+03:00",
#      "dateModified": "2020-11-07T19:56:28+03:00",
#      "author": {
#      "@type": "Person",
#      "name": "صالح الحربي (جدة) saleh_a_alharbi@"
#      },
#      "publisher": {
#      "@type": "Organization",
#      "name": "okaz",
#      "logo": {
#      "@type": "ImageObject",
#      "url": "https://www.okaz.com.sa/themes/okazksa/images/new-okazlogo.png",
#      "width": 393,
#      "height": 108
#      }
#      },
#      "description": "الليث يقلبها على الفتح ويقفز للوصافة"
#      }
#  </script>
#  <div class="socialFixOuter hidden-xs">
#  <a class="socialFix" href="https://twitter.com/okaz_online" style="background-image: url(images/socialFix/twitter.jpg);background-color: #00aced;" target="_blank"></a>
#  <a class="socialFix" href="https://www.facebook.com/OKAZNEWS" style="background-image: url(images/socialFix/facebook.jpg);background-color: #3765a3;" target="_blank"></a>
#  <a class="socialFix" href="https://www.snapchat.com/add/Okaz1" style="background-image: url(images/socialFix/snapchat.jpg);background-color: #fffc00;" target="_blank"></a>
#  <a class="socialFix" href="https://instagram.com/okaznewspaper/" style="background-image: url(images/socialFix/instagram.jpg);background-color: #bebebe;" target="_blank"></a>
#  <a class="socialFix" href="/rss" style="background-image: url(images/socialFix/rss.jpg);background-color: #ff7b0a;" target="_blank"></a>
#  <a class="socialFix" href="https://www.youtube.com/user/okazonline" style="background-image: url(images/socialFix/youtube.jpg);background-color: #e41d2f" target="_blank"></a>
#  <a class="socialFix" href="https://telegram.me/okaz_sa" style="background-image: url(images/socialFix/telegram.png); background-color: #2299d6;"></a>
#  </div>
#  </div>
#  <script type="text/javascript">
#                              var HttpClient = function () {
#                                  this.get = function (aUrl, aCallback) {
#                                      var anHttpRequest = new XMLHttpRequest();
#                                      anHttpRequest.onreadystatechange = function () {
#                                          if (anHttpRequest.readyState == 4 && anHttpRequest.status == 200)
#                                              aCallback(anHttpRequest.responseText);
#                                      }
#
#                                      anHttpRequest.open("GET", aUrl, true);
#                                      anHttpRequest.send(null);
#                                  }
#                              }
#
#                              function incrementArticleVisitcount(articleId) {
#                                  var article_counter_url = "/ajax/article_count/" + articleId + "?ts=" + Date.now();
#                                  var client = new HttpClient();
#                                  client.get(article_counter_url, function (response) {
#                                      console.log(response);
#                                  });
#                              }
#
#                              //                var articleId = (document.getElementById('cmsArticleId'));
#                              //                if (articleId) {
#                              //                    incrementArticleVisitcount(articleId.value);
#                              //                }
#                              </script>
#  <footer class="footer" id="mainFooter">
#  <div class="footer-content">
#  <div class="shell">
#  <div class="footer-cols">
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div><!-- /.footer-cols -->
#  </div><!-- /.shell -->
#  </div><!-- /.footer-content -->
#  <div class="footer-bar">
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div><!-- /.shell -->
#  </div><!-- /.footer-bar -->
#  <!--<div class="newsPress">
#  	<span>Powered by <a href="http://layoutintl.com" target="_blank">NewsPress</a></span>
#  </div>-->
#  <input id="FOOTER_HEIGHT" type="hidden" value="">
#  </input></footer>
#  <script>
#                                  function EmbedScript() {
#                                      var _Impulser = window.parent.document.createElement('script');
#                                      _Impulser.type = 'text/javascript';
#                                      _Impulser.async = true;
#                                      _Impulser.src = ('https:' == window.parent.document.location.protocol ? 'https://' : 'http://') + 'impulse.forkcdn.com/impulse3/config/impulse.js';
#                                      var _scripter = window.parent.document.getElementsByTagName('script')[0];
#                                      _scripter.parentNode.insertBefore(_Impulser, _scripter);
#                                  }
#                                  ;
#                                  function inIframe() {
#                                      try {
#                                          return window.self !== window.top;
#                                      } catch (e) {
#                                          return true;
#                                      }
#                                  }
#                                  if (inIframe()) {
#                                      window.parent.$ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                      EmbedScript();
#                                  } else {
#                                      $ImpulseID = "IMPL-OKAZ-OKAZ-RESP-GENERIC";
#                                      EmbedScript();
#                                  }
#                              </script>
#  <!-- the arrows for big-page -->
#  <script src="images/icons/grunticon.loader.js" type="text/javascript"></script>
#  <script>
#                                  grunticon(["images/icons/icons.data.svg.css", "images/icons/icons.data.png.css", "images/icons/icons.fallback.css"], grunticon.svgLoadedCallback);
#                              </script>
#  <!-- the arrows for big-page -->
#  <script async="" rel="preconnect" src="//pagead2.googlesyndication.com/pagead/js/adsbygoogle.js"></script>
#  <script crossorigin="anonymous" integrity="sha256-FgpCb/KJQlLNfOu91ta32o/NMZxltwRo8QtmkMRdAu8=" src="https://code.jquery.com/jquery-3.3.1.min.js"></script>
#  <!-- Fall back to a local copy of jQuery if the CDN fails-->
#  <noscript><script src="https://www.okaz.com.sa/js/jquery.min.js"></script></noscript>
#  <script defer="" src="https://www.okaz.com.sa/themes/okazksa/js/script-one.js?v=0.73"></script><!--515kb-->
#  <!-- Go to www.addthis.com/dashboard to customize your tools replace  async="async" by defer -->
#  <script defer="" rel="preconnect" src="//s7.addthis.com/js/300/addthis_widget.js&amp;async=1#pubid=ra-57d7a6b3b67f6bef" type="text/javascript"></script>
#  <!--Vibe_okaz-->
#  <script async="" id="_forkIAVScript" src="//vibecdn.forkcdn.com/Inarticle/iav.js?publisher=okaz"></script>
#  <noscript><a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a97c95f6&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4210&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a97c95f6"/></a></noscript>
#  <noscript><a href="http://adnet.forkcdn.com/www/delivery/ck.php?n=a87267e0&amp;cb=INSERT_RANDOM_NUMBER_HERE" target="_blank"><img alt="" src="http://adnet.forkcdn.com/www/delivery/avw.php?zoneid=4211&amp;cb=INSERT_RANDOM_NUMBER_HERE&amp;n=a87267e0"/></a></noscript>
#  <!--Vibe_okaz-->
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg">
#  </img></div>
#  <script>
#  								$(function(){
#  									$(window).scroll(function(){
#  										if($(window).scrollTop() > 100){
#  											$(".stickyAdsBottom").css("display","block");
#  										}else{
#  											$(".stickyAdsBottom").css("display","none");
#  										}
#  									});
# ...
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div><!-- /.footer-cols -->
#  </div>,
#  <div class="footer-cols">
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>
#  <a class="footerText"></a>
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div><!-- /.footer-col -->
#  </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #00dac1">
#  <a href="https://www.okaz.com.sa/news">أخبار</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/local">محليات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/news/politics">سياسة</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #11e944">
#  <a href="https://www.okaz.com.sa/sports">رياضة</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/international">الدولية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/miscellaneous-games">العاب منوعة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/sport/special-interviews">مقابلات خاصة</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #40d1f2">
#  <a href="https://www.okaz.com.sa/economy">اقتصاد</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/saudi">السعودية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/arabian">العربية</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/economy/international">الدولية</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b156db">
#  <a href="https://www.okaz.com.sa/culture">ثقافة و فن</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/art">فن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/culture">ثقافة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/culture/other">اخرى</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #a8ad9b">
#  <a href="https://www.okaz.com.sa/souk-okaz">سوق عكاظ</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/property">عقار</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/souk-okaz/haraj">حراج</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title" style="border-color: #b07564">
#  <a href="https://www.okaz.com.sa/articles">مقالات</a>
#  </h5><!-- /.footer-title footer-title-red -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/authors">كتاب الرأي</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/morearticles/articles/people-voice">نبض القراء</a>
#  </li>
#  </ul> </div>,
#  <div class="footer-col">
#  <h5 class="footer-title footer-title-lightgrey">المزيد</h5><!-- /.footer-title footer-title-lightgrey -->
#  <ul>
#  <li>
#  <a href="https://www.okaz.com.sa/saudi-women">سعوديات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/fashion">أزياء</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/tourism">سياحة</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/people-situations">احوال الناس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/investigation">تحقيقات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/technology">تكنولوجيا</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/citizen-voice">صوت المواطن</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/weather">حالة الطقس</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/variety">منوعات</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/Games">ألعاب</a>
#  </li>
#  <li>
#  <a href="https://www.okaz.com.sa/special-zones">زوايا متخصصة</a>
#  </li>
#  </ul>
#  </div>,
#  <div class="footer-bar">
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div><!-- /.shell -->
#  </div>,
#  <div class="shell">
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div><!-- /.footer-inner -->
#  <nav class="footer-nav">
#  <ul>
#  <li>
#  <a class="js-panel-toggle" data-target="#disclaimer" onclick="openDisclaimer()" role="button">الشروط والأحكام</a>
#  </li>
#  <li>
#  <a href="../../about-us">حول المؤسسة</a>
#  </li>
#  <li>
#  <a href="../../editorial-management">إدارة التحرير</a>
#  </li>
#  <!--				<li>
#  					<a href="../../advertise-with-us" >للإعلان</a>
#  				</li>-->
#  <li>
#  <a href="../../media-kit">للإعلان</a>
#  </li>
#  <li>
#  <a href="../../contact-us">إتصل بنا</a>
#  </li>
#  <li>
#                      حقوق الملكية ©  <span class="okazcopyright"></span> <span>عكاظ</span> 2020. جميع الحقوق محفوظة
#  				</li>
#  </ul>
#  </nav><!-- /.footer-nav -->
#  </div>,
#  <div class="footer-inner">
#  <a class="logo" href="https://www.okaz.com.sa/"></a>
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div><!-- /.socials -->
#  </div>,
#  <div class="storeBadges">
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>
#  </div>,
#  <div class="appleBadge">
#  <a href="https://apps.apple.com/us/app/okaz-عكاظ/id1464923584?ls=1" target="_blank"></a>
#  </div>,
#  <div class="googleBadge">
#  <a href="https://play.google.com/store/apps/details?id=com.apps2you.okaz" target="_blank">
#  </a>
#  </div>,
#  <div class="socials">
#  <ul>
#  <li>
#  <a onclick="window.open('https://www.facebook.com/OKAZNEWS', '_blank');">
#  <i class="fa fa-facebook"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://twitter.com/okaz_online', '_blank');">
#  <i class="fa fa-twitter"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.instagram.com/okaznewspaper/', '_blank');">
#  <i class="fa fa-instagram"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a href="#">
#  <i class="fa fa-linkedin"></i>
#  </a>
#  </li>
#  <li style="display: none;">
#  <a onclick="window.open('', '_blank');">
#  <i class="fa fa-google-plus"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.youtube.com/user/okazonline', '_blank');">
#  <i class="fa fa-youtube-play"></i>
#  </a>
#  </li>
#  <li style="display: none">
#  <a href="#">
#  <i class="fa fa-pinterest"></i>
#  </a>
#  </li>
#  <li>
#  <a onclick="window.open('https://www.okaz.com.sa/../../rss', '_blank');">
#  <i class="fa fa-rss"></i>
#  </a>
#  </li>
#  </ul>
#  </div>,
#  <div class="ajax-loader">
#  <img alt="loader" class="img-responsive" src="images/small_loader.svg">
#  </img></div>,
#  <div>
#  <!-- Desktop+Mobile Banner -->
#  <div id="div-gpt-ad-1x1">
#  <script>
#  									googletag.cmd.push(function() { googletag.display('div-gpt-ad-1x1'); });
#  								  </script>
#  </div>
#  </div>,
#  <div id="div-gpt-ad-1x1">
#  <script>
#  									googletag.cmd.push(function() { googletag.display('div-gpt-ad-1x1'); });
#  								  </script>
#  </div>]

# %%
text = soup.find('div', attrs={"class":"bodyText"})
text

# %%
HTMLParser().unescape(text)
# Out:
# <ipython-input-117-5c6b6c3a9452>:1: DeprecationWarning: The unescape method is deprecated and will be removed in 3.5, use html.unescape() instead.
#   HTMLParser().unescape(text)
# [<div class="bodyText">
#                                                      قلب فريق الشباب تأخره بهدف من أمام مضيفه الفتح إلى فوز مستحق بثلاثة أهداف لهدف، في اللقاء الذي جمع بينهما على استاد مدينة الأمير عبدالله بن جلوي، ضمن لقاءات جولة «لنلهم العالم بقمتنا» لدوري كأس الأمير محمد بن سلمان للمحترفين.<br/><br/>بدأ الشباب بهجمات متتالية وسط تحفظ دفاعي من الفتح الذي استغل هجمة مرتدة قادها جوستاف ليتحصل على ركلة جزاء تقدم لها سفيان بن دبكة ليحرز الهدف الأول للفتح (د:37).<!--mobileAd--><div class="ads-preview"><div id="leftsidebar3"><script>window.googletag = window.googletag || {cmd: []};googletag.cmd.push(function() {googletag.defineSlot('/3387746/okaz_com_sa_news/leftsidebar3', [[360, 300], [336, 280], [300, 250]],'leftsidebar3').addService(googletag.pubads());googletag.enableServices();googletag.display('leftsidebar3');});</script></div></div><br/><br/>وفي الشوط الثاني قلب الشباب الطاولة على الفتح وأحرز هدفين في خمس دقائق، وفي الوقت بدل الضائع أضاف الهدف الثالث، وجاءت الأهداف الثلاثة للشباب عن طريق كل من: تركي العمار (هدفين د:74، 90+6)، وفابيو مارتينز (د:78)، ومنح حكم اللقاء فيصل البلوي بطاقة حمراء للاعب الفتح حسن الحبيب (د:85)، وبعد 8 دقائق كوقت بدل ضائع أعلن الحكم نهاية اللقاء بفوز الشباب بهدفين لهدف.<br/><br/>وبهذه النتيجة قفز الشباب للمركز الثاني برصيد 10 نقاط، متساوياً مع المتصدر الهلال الذي يتفوق بفارق الأهداف، فيما تجمد رصيد الفتح عند 7 نقاط في المركز الخامس.<div class="clear"></div><br><div class="pagingWrap" style="display:none;"><a class="button grey prevBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=0" style="display:none;">&lt; Previous Page</a><a class="button grey nextBtn" href="https://www.okaz.com.sa/article/2047423/رياضة?page=2" style="display:none;">Next Page &gt;</a></div> </br></div>]

# %%
from bs4 import BeautifulSoup
from bs4.element import Comment
import urllib.request


def tag_visible(element):
    if element.parent.name in ['style', 'script', 'head', 'title', 'meta', '[document]']:
        return False
    if isinstance(element, Comment):
        return False
    return True


def text_from_html(body):
    soup = BeautifulSoup(body, 'html.parser')
    texts = soup.findAll(text=True)
    visible_texts = filter(tag_visible, texts)  
    return u" ".join(t.strip() for t in visible_texts)

html = urllib.request.urlopen('https://www.okaz.com.sa/sport/saudi/2047423').read().
print(text_from_html(html))
